# %%
# Reading an excel file using Python
import numpy as np
import pandas as pd
import json

# %% [markdown]
# ### final dataset shape
# df_names = ["year", "month", "city", "district", "price_riyals", "area_m2", "no_deals", "status", "realstate_cls", "realstate_type"]

# %% [markdown]
# ## Makkah al-Mukarramah

# %%
# read excel file, sheet name 
df_Makkah = pd.read_excel("data/raw/realestate-for-distiricts-on-2018-2019-2020-2021.xlsx", sheet_name=2)

# %%
# explore the sheet for studying its structure
df_Makkah.head(30)
# Out:
#                                            Unnamed: 0             Unnamed: 1  \
# 0     المؤشر العقاري للأحياء بمدينة مكة المكرمة في...                    NaN
# 1                                                 NaN                    NaN
# 2                                             المدينة            مكة المكرمة
# 3                       حالة العملية(معتمدة/ملغية/..)                 معتمدة
# 4                                                 NaN                    NaN
# 5                                                 NaN                    NaN
# 6                                                 NaN                   2018
# 7                                             الأحياء  السعر بالريال السعودي
# 8                                        حي/1/ 20/ 27                 550000
# 9                                               يناير                    NaN
# 10                                              يوليو                    NaN
# 11                                             اوغسطس                    NaN
# 12                                             نوفمبر                 550000
# 13                                    حي/1/ 29/ 10/ أ                    NaN
# 14                                              يناير                    NaN
# 15                                        حي/1/ 32/ 1                    NaN
# 16                                               مارس                    NaN
# 17                                    حي/1/ 32/ 16/ أ                    NaN
# 18                                             اوغسطس                    NaN
# 19                          حي/45 بطحاء قريش النموذجى                2380000
# 20                                              يناير                    NaN
# 21                                             فبراير                 700000
# 22                                               مارس                 300000
# 23                                              ابريل                1380000
# 24                                        حي/أبو مراغ                3125000
# 25                                             فبراير                 550000
# 26                                               مارس                    NaN
# 27                                              ابريل                    NaN
# 28                                               مايو                 310000
# 29                                              يوليو                1200000
#
#                Unnamed: 2   Unnamed: 3             Unnamed: 4  \
# 0                     NaN          NaN                    NaN
# 1                     NaN          NaN                    NaN
# 2                     NaN          NaN                    NaN
# 3                     NaN          NaN                    NaN
# 4                     NaN          NaN                    NaN
# 5                     NaN          NaN                    NaN
# 6                     NaN          NaN                   2019
# 7   المساحة بالمتر المربع  عدد الصفقات  السعر بالريال السعودي
# 8                     550            1                1670000
# 9                     NaN          NaN                 540000
# 10                    NaN          NaN                 530000
# 11                    NaN          NaN                 600000
# 12                    550            1                    NaN
# 13                    NaN          NaN                    NaN
# 14                    NaN          NaN                    NaN
# 15                    NaN          NaN                    NaN
# 16                    NaN          NaN                    NaN
# 17                    NaN          NaN                    NaN
# 18                    NaN          NaN                    NaN
# 19                 691.45            4                    NaN
# 20                    NaN          NaN                    NaN
# 21                 161.82            1                    NaN
# 22                 135.33            1                    NaN
# 23                  394.3            2                    NaN
# 24                2262.67            6                2564900
# 25                    394            1                    NaN
# 26                    NaN          NaN                 750000
# 27                    NaN          NaN                1199000
# 28                  169.2            1                    NaN
# 29                 439.47            1                    NaN
#
#                Unnamed: 5   Unnamed: 6             Unnamed: 7  \
# 0                     NaN          NaN                    NaN
# 1                     NaN          NaN                    NaN
# 2                     NaN          NaN                    NaN
# 3                     NaN          NaN                    NaN
# 4                     NaN          NaN                    NaN
# 5                     NaN          NaN                    NaN
# 6                     NaN          NaN                   2020
# 7   المساحة بالمتر المربع  عدد الصفقات  السعر بالريال السعودي
# 8                     844            3                1132313
# 9                     172            1                    NaN
# 10                    172            1                1132313
# 11                    500            1                    NaN
# 12                    NaN          NaN                    NaN
# 13                    NaN          NaN                1550000
# 14                    NaN          NaN                1550000
# 15                    NaN          NaN                    NaN
# 16                    NaN          NaN                    NaN
# 17                    NaN          NaN                 300000
# 18                    NaN          NaN                 300000
# 19                    NaN          NaN                1390000
# 20                    NaN          NaN                 790000
# 21                    NaN          NaN                 600000
# 22                    NaN          NaN                    NaN
# 23                    NaN          NaN                    NaN
# 24                1812.95            4                1853279
# 25                    NaN          NaN                    NaN
# 26                  562.5            1                    NaN
# 27                    394            1                    NaN
# 28                    NaN          NaN                    NaN
# 29                    NaN          NaN                 503279
#
#                Unnamed: 8   Unnamed: 9            Unnamed: 10  \
# 0                     NaN          NaN                    NaN
# 1                     NaN          NaN                    NaN
# 2                     NaN          NaN                    NaN
# 3                     NaN          NaN                    NaN
# 4                     NaN          NaN                    NaN
# 5                     NaN          NaN                    NaN
# 6                     NaN          NaN                   2021
# 7   المساحة بالمتر المربع  عدد الصفقات  السعر بالريال السعودي
# 8                     460            1                    NaN
# 9                     NaN          NaN                    NaN
# 10                    460            1                    NaN
# 11                    NaN          NaN                    NaN
# 12                    NaN          NaN                    NaN
# 13                  612.5            1                1700000
# 14                  612.5            1                1700000
# 15                    NaN          NaN                 800000
# 16                    NaN          NaN                 800000
# 17                    600            1                    NaN
# 18                    600            1                    NaN
# 19                 368.91            2                    NaN
# 20                 197.15            1                    NaN
# 21                 171.76            1                    NaN
# 22                    NaN          NaN                    NaN
# 23                    NaN          NaN                    NaN
# 24                   1378            3                1185000
# 25                    NaN          NaN                 200000
# 26                    NaN          NaN                  10000
# 27                    NaN          NaN                 975000
# 28                    NaN          NaN                    NaN
# 29                    400            1                    NaN
#
#               Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  \
# 0                     NaN          NaN          NaN          NaN          NaN
# 1                     NaN          NaN          NaN          NaN          NaN
# 2                     NaN          NaN          NaN          NaN          NaN
# 3                     NaN          NaN          NaN          NaN          NaN
# 4                     NaN          NaN          NaN          NaN          NaN
# 5                     NaN          NaN          NaN          NaN          NaN
# 6                     NaN          NaN          NaN          NaN          NaN
# 7   المساحة بالمتر المربع  عدد الصفقات          NaN          NaN          NaN
# 8                     NaN          NaN          NaN          NaN          NaN
# 9                     NaN          NaN          NaN          NaN          NaN
# 10                    NaN          NaN          NaN          NaN          NaN
# 11                    NaN          NaN          NaN          NaN          NaN
# 12                    NaN          NaN          NaN          NaN          NaN
# 13                  612.5            1          NaN          NaN          NaN
# 14                  612.5            1          NaN          NaN          NaN
# 15                  721.8            1          NaN          NaN          NaN
# 16                  721.8            1          NaN          NaN          NaN
# 17                    NaN          NaN          NaN          NaN          NaN
# 18                    NaN          NaN          NaN          NaN          NaN
# 19                    NaN          NaN          NaN          NaN          NaN
# 20                    NaN          NaN          NaN          NaN          NaN
# 21                    NaN          NaN          NaN          NaN          NaN
# 22                    NaN          NaN          NaN          NaN          NaN
# 23                    NaN          NaN          NaN          NaN          NaN
# 24                   2279            3          NaN          NaN          NaN
# 25                    625            1          NaN          NaN          NaN
# 26                    394            1          NaN          NaN          NaN
# 27                   1260            1          NaN          NaN          NaN
# 28                    NaN          NaN          NaN          NaN          NaN
# 29                    NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 16  Unnamed: 17
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# 5           NaN          NaN
# 6           NaN          NaN
# 7           NaN          NaN
# 8           NaN          NaN
# 9           NaN          NaN
# 10          NaN          NaN
# 11          NaN          NaN
# 12          NaN          NaN
# 13          NaN          NaN
# 14          NaN          NaN
# 15          NaN          NaN
# 16          NaN          NaN
# 17          NaN          NaN
# 18          NaN          NaN
# 19          NaN          NaN
# 20          NaN          NaN
# 21          NaN          NaN
# 22          NaN          NaN
# 23          NaN          NaN
# 24          NaN          NaN
# 25          NaN          NaN
# 26          NaN          NaN
# 27          NaN          NaN
# 28          NaN          NaN
# 29          NaN          NaN

# %%
# sheet size
df_Makkah.shape
# Out:
# (6029, 18)

# %%
# current columns names
df_Makkah.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17'],
#       dtype='object')

# %%
# current statistics of sheet 
df_Makkah.describe(include = "all")
# Out:
#        Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# count        6025      2965.0      2962.0      2962.0      3162.0      3161.0
# unique       1163      1466.0      2121.0        76.0      1583.0      2238.0
# top        فبراير    100000.0       400.0         1.0    500000.0       400.0
# freq          472       111.0        97.0      1475.0        74.0       115.0
# mean          NaN         NaN         NaN         NaN         NaN         NaN
# std           NaN         NaN         NaN         NaN         NaN         NaN
# min           NaN         NaN         NaN         NaN         NaN         NaN
# 25%           NaN         NaN         NaN         NaN         NaN         NaN
# 50%           NaN         NaN         NaN         NaN         NaN         NaN
# 75%           NaN         NaN         NaN         NaN         NaN         NaN
# max           NaN         NaN         NaN         NaN         NaN         NaN
#
#         Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# count       3161.0      3327.0      3326.0      3326.0       1256.0
# unique        85.0      1658.0      2383.0        90.0        607.0
# top            1.0    350000.0       400.0         1.0    1000000.0
# freq        1520.0        63.0       113.0      1648.0         46.0
# mean           NaN         NaN         NaN         NaN          NaN
# std            NaN         NaN         NaN         NaN          NaN
# min            NaN         NaN         NaN         NaN          NaN
# 25%            NaN         NaN         NaN         NaN          NaN
# 50%            NaN         NaN         NaN         NaN          NaN
# 75%            NaN         NaN         NaN         NaN          NaN
# max            NaN         NaN         NaN         NaN          NaN
#
#         Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  \
# count        1255.0       1255.0          0.0          0.0          0.0
# unique        870.0         58.0          NaN          NaN          NaN
# top           400.0          1.0          NaN          NaN          NaN
# freq           32.0        602.0          NaN          NaN          NaN
# mean            NaN          NaN          NaN          NaN          NaN
# std             NaN          NaN          NaN          NaN          NaN
# min             NaN          NaN          NaN          NaN          NaN
# 25%             NaN          NaN          NaN          NaN          NaN
# 50%             NaN          NaN          NaN          NaN          NaN
# 75%             NaN          NaN          NaN          NaN          NaN
# max             NaN          NaN          NaN          NaN          NaN
#
#         Unnamed: 16  Unnamed: 17
# count           0.0          0.0
# unique          NaN          NaN
# top             NaN          NaN
# freq            NaN          NaN
# mean            NaN          NaN
# std             NaN          NaN
# min             NaN          NaN
# 25%             NaN          NaN
# 50%             NaN          NaN
# 75%             NaN          NaN
# max             NaN          NaN

# %% [markdown]
# ## Saving data before cleaning and reshaping

# %%
# retrieving all rows and some columns by iloc method 
df_status = df_Makkah.iloc [3, 1]
df_status
# Out:
# 'معتمدة'

# %%
# retrieving all rows and some columns by iloc method 
df_city_name = df_Makkah.iloc[2, 1]
df_city_name
# Out:
# 'مكة المكرمة'

# %% [markdown]
# ## Cleaning process

# %%
# rename first column to month
df_Makkah = df_Makkah.rename(columns ={df_Makkah.columns[0] : 'month'})
df_Makkah
# Out:
#                                                   month   Unnamed: 1  \
# 0       المؤشر العقاري للأحياء بمدينة مكة المكرمة في...          NaN
# 1                                                   NaN          NaN
# 2                                               المدينة  مكة المكرمة
# 3                         حالة العملية(معتمدة/ملغية/..)       معتمدة
# 4                                                   NaN          NaN
# ...                                                 ...          ...
# 6024                                             سبتمبر          NaN
# 6025                                             نوفمبر          NaN
# 6026                                             ديسمبر          NaN
# 6027  حي/يمين الذاهب الى الليث بمكة المكرمة بطريق ال...      1000000
# 6028                                              يوليو      1000000
#
#      Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0           NaN        NaN        NaN        NaN        NaN        NaN
# 1           NaN        NaN        NaN        NaN        NaN        NaN
# 2           NaN        NaN        NaN        NaN        NaN        NaN
# 3           NaN        NaN        NaN        NaN        NaN        NaN
# 4           NaN        NaN        NaN        NaN        NaN        NaN
# ...         ...        ...        ...        ...        ...        ...
# 6024        NaN        NaN        NaN        NaN        NaN     250000
# 6025        NaN        NaN        NaN        NaN        NaN     300000
# 6026        NaN        NaN        NaN        NaN        NaN    1360000
# 6027   58029.51          1        NaN        NaN        NaN        NaN
# 6028   58029.51          1        NaN        NaN        NaN        NaN
#
#      Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  Unnamed: 13  \
# 0           NaN        NaN         NaN         NaN         NaN          NaN
# 1           NaN        NaN         NaN         NaN         NaN          NaN
# 2           NaN        NaN         NaN         NaN         NaN          NaN
# 3           NaN        NaN         NaN         NaN         NaN          NaN
# 4           NaN        NaN         NaN         NaN         NaN          NaN
# ...         ...        ...         ...         ...         ...          ...
# 6024     616.24          2         NaN         NaN         NaN          NaN
# 6025      310.9          1         NaN         NaN         NaN          NaN
# 6026     1216.3          3         NaN         NaN         NaN          NaN
# 6027        NaN        NaN         NaN         NaN         NaN          NaN
# 6028        NaN        NaN         NaN         NaN         NaN          NaN
#
#       Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17
# 0             NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...
# 6024          NaN          NaN          NaN          NaN
# 6025          NaN          NaN          NaN          NaN
# 6026          NaN          NaN          NaN          NaN
# 6027          NaN          NaN          NaN          NaN
# 6028          NaN          NaN          NaN          NaN
#
# [6029 rows x 18 columns]

# %%
# adding الأحياء
df_Makkah.insert(loc = 1, column= 'district', value= '')
df_Makkah
# Out:
#                                                   month district   Unnamed: 1  \
# 0       المؤشر العقاري للأحياء بمدينة مكة المكرمة في...                   NaN
# 1                                                   NaN                   NaN
# 2                                               المدينة           مكة المكرمة
# 3                         حالة العملية(معتمدة/ملغية/..)                معتمدة
# 4                                                   NaN                   NaN
# ...                                                 ...      ...          ...
# 6024                                             سبتمبر                   NaN
# 6025                                             نوفمبر                   NaN
# 6026                                             ديسمبر                   NaN
# 6027  حي/يمين الذاهب الى الليث بمكة المكرمة بطريق ال...               1000000
# 6028                                              يوليو               1000000
#
#      Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0           NaN        NaN        NaN        NaN        NaN        NaN
# 1           NaN        NaN        NaN        NaN        NaN        NaN
# 2           NaN        NaN        NaN        NaN        NaN        NaN
# 3           NaN        NaN        NaN        NaN        NaN        NaN
# 4           NaN        NaN        NaN        NaN        NaN        NaN
# ...         ...        ...        ...        ...        ...        ...
# 6024        NaN        NaN        NaN        NaN        NaN     250000
# 6025        NaN        NaN        NaN        NaN        NaN     300000
# 6026        NaN        NaN        NaN        NaN        NaN    1360000
# 6027   58029.51          1        NaN        NaN        NaN        NaN
# 6028   58029.51          1        NaN        NaN        NaN        NaN
#
#      Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  Unnamed: 13  \
# 0           NaN        NaN         NaN         NaN         NaN          NaN
# 1           NaN        NaN         NaN         NaN         NaN          NaN
# 2           NaN        NaN         NaN         NaN         NaN          NaN
# 3           NaN        NaN         NaN         NaN         NaN          NaN
# 4           NaN        NaN         NaN         NaN         NaN          NaN
# ...         ...        ...         ...         ...         ...          ...
# 6024     616.24          2         NaN         NaN         NaN          NaN
# 6025      310.9          1         NaN         NaN         NaN          NaN
# 6026     1216.3          3         NaN         NaN         NaN          NaN
# 6027        NaN        NaN         NaN         NaN         NaN          NaN
# 6028        NaN        NaN         NaN         NaN         NaN          NaN
#
#       Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17
# 0             NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...
# 6024          NaN          NaN          NaN          NaN
# 6025          NaN          NaN          NaN          NaN
# 6026          NaN          NaN          NaN          NaN
# 6027          NaN          NaN          NaN          NaN
# 6028          NaN          NaN          NaN          NaN
#
# [6029 rows x 19 columns]

# %%
# list of arabic months
months_names = [
    'يناير',
    'فبراير',
    'مارس',
    'ابريل',
    'مايو',
    'يونيو',
    'يوليو',
    'اوغسطس',
    'سبتمبر',
    'اكتوبر',
    'نوفمبر',
    'ديسمبر'
]

# %%
# create empty list to save the indexs of district name 
list_redundant =[]

# create a range of number for do the operation at every row in dataset
x = range(8, df_Makkah.shape[0], 1)


for i in x:
    # check if it is district then save this didtric name and it's index
    if (df_Makkah.iloc [i, 0] not in months_names):
        print(df_Makkah.iloc [i, 0], '-----', df_Makkah.index[i])
        temp = df_Makkah.iloc [i, 0]
        list_redundant.append(df_Makkah.index[i])  
        
    # else if it is a month set its district name                      
    elif (df_Makkah.iloc [i, 0] in months_names):
            df_Makkah.iloc [i, 1] = temp
# Out:
# حي/1/ 20/ 27 ----- 8
# حي/1/ 29/ 10/ أ ----- 13
# حي/1/ 32/ 1 ----- 15
# حي/1/ 32/ 16/ أ ----- 17
# حي/45 بطحاء قريش النموذجى ----- 19
# حي/أبو مراغ ----- 24
# حي/أبو مراغ رقم 3 ----- 34
# حي/أخرى ----- 36
# حي/أم الجود ----- 49
# حي/أم الجود مخطط الحمراء ----- 57
# حي/أم الراكه بأرض وادى ضيم ----- 59
# حي/ابو لهب بمحلة جرول ----- 63
# حي/ابو مراغ ----- 65
# حي/ابو مراغ رقم 3 ----- 71
# حي/ابو مراغ على يمين الذاهب الى المدينة المنورة ----- 76
# حي/ابو مراغ على يمين الذاهب الى وادى فاطمه ----- 80
# حي/ابى مراغ ----- 85
# حي/ابى مراغ على يمين الذاهب الى وادى فاطمه ----- 95
# حي/ابى مرو ----- 102
# حي/اجياد ----- 104
# حي/اجياد المصافى ----- 108
# حي/اجياد جبل السبع البنات ----- 112
# حي/اجياد دحلة اللبان ----- 117
# حي/اجياد ريع بخش ----- 119
# حي/اراضى الشوقية ----- 124
# حي/اراضى بدر ----- 131
# حي/اراضى بدر فيصل ----- 134
# حي/ارض الشيخ احمد زينى ----- 137
# حي/ارض المرور بالعمرة ----- 141
# حي/اضافة جزء من محبس الجن الضفة الشمالية ب ----- 143
# حي/اعادة تخطيط وتنضيم ارض الرصيفه الجديده ----- 145
# حي/اعادة تخطيط وتنظيم ارض الرصيفة الجديدة ----- 147
# حي/اعلى جبل ابو مطشش ----- 149
# حي/الأمير عبدالله الفيصل المعتمد ----- 151
# حي/الأمير محمد بطحاء قريش النموذجى المعدل ----- 155
# حي/الاباء والميسوره ----- 161
# حي/الاسكان العام ----- 164
# حي/الاسكان العام بالرصيفة ----- 166
# حي/الاسكان العام بالرصيفه ----- 179
# حي/الاسكان العام بمكة حى الملك فهد ----- 181
# حي/الاسكان العام حى الملك فهد ----- 183
# حي/الاشراف من محلة جرول ----- 191
# حي/الامير احمد ----- 193
# حي/الامير احمد بالرصيفة ----- 196
# حي/الامير احمد باللاحجه من جهة المسفلة ----- 198
# حي/الامير احمد بكدى ----- 200
# حي/الامير احمد بن عبدالعزيز بكدى المسفله ----- 212
# حي/الامير مشعل بالششه ----- 215
# حي/الامير مشعل بن عبدالعزيز خلف المدرسة ----- 217
# حي/البحيرات ----- 219
# حي/البحيرات امتداد المنطقة الصناعية بالعمرة رقم 2 ----- 232
# حي/البحيرات بالطريق المؤدى فاطمة بالمخطط رقم 3 ----- 234
# حي/البحيرات طريق الوادى ----- 236
# حي/البحيرات على يسار الذاهب الى وادى فاطمة ----- 239
# حي/البدر المعدل بكدى رقم 2 ----- 246
# حي/البديوى طريق الطائف القديم يمين الذاهب الى الطائف ----- 251
# حي/البركة ----- 253
# حي/البوابة رقم 1 المعدل التخصصى ----- 255
# حي/البوابة رقم 1 حى التخصصى ----- 257
# حي/البوابة رقم 11 ----- 259
# حي/البوابة رقم 3 ----- 262
# حي/البوابة رقم 6 ----- 273
# حي/البوابة رقم 8 ----- 276
# حي/البوابة رقم واحد التخصصى المعتمد ----- 284
# حي/البوابه رقم 7 ----- 287
# حي/البوابه رقم 8 ----- 297
# حي/التخصصى ----- 304
# حي/التخصصى المعتمد ----- 317
# حي/التخصصى رقم 1 ----- 330
# حي/التنعيم ----- 332
# حي/التنعيم 13 ----- 342
# حي/التنعيم 4 ----- 344
# حي/التنعيم بحى العمرة ----- 357
# حي/التنعيم بشعب صايف ----- 360
# حي/التنعيم رقم 2 ----- 362
# حي/التنعيم رقم 3 ----- 365
# حي/التنعيم رقم 4 ----- 378
# حي/الجزء الخارج عن صك مخطط الحمراء ----- 391
# حي/الجزء الخارج عن صك مخطط فيصل بدر ----- 395
# حي/الجزء المتبقى بامتداد حى الزاهر ----- 397
# حي/الجزء المتبقى من اراضى الشوقية ----- 399
# حي/الجعرانة ----- 411
# حي/المشمس الواقع بالنواريةعلى يسار الذاهب لوادى فاطمة ----- 2386
# حي/المصافى من محلة اجياد ----- 2388
# حي/المعابدة ----- 2390
# حي/المعابدة الجميزة حارة الكوشه ----- 2403
# حي/المعابدة الجميزة حارة بيشة ----- 2405
# حي/المعابدة الخانسة ----- 2407
# حي/المعابدة الملاوى ----- 2414
# حي/المعابدة الملاوى جبل خندمة ----- 2423
# حي/المعابدة بالجميزة ----- 2425
# حي/المعابدة بالخندرية ----- 2429
# حي/المعابدة بالشرقاوية ----- 2431
# حي/المعابدة بالغسالة ----- 2433
# حي/المعابدة بالكندرة ----- 2436
# حي/المعابدة بجبل القلعة ----- 2438
# حي/المعابدة بحى الروضة ----- 2440
# حي/المعابدة بوادى جليل ----- 2442
# حي/المعابدة تحت جبل النور ----- 2445
# حي/المعابدة حارة اكلب ----- 2447
# حي/المعابدة حارة لقيطة ----- 2450
# حي/المعابدة دحلة ضبع ----- 2453
# حي/المعابدة رقم 2 ----- 2457
# حي/المعابدة رقم 5 المعدل ورش اضافات ----- 2460
# حي/المعابدة ريع ذاخر ----- 2462
# حي/المعابدة ريع ذاخر المخطط رقم اثنان ----- 2471
# حي/المعابدة شارع الحج ----- 2475
# حي/المعابدة شرق شارع الحج ----- 2480
# حي/المعابدة شعبة الاجابة ----- 2487
# حي/المعابدة شمال شارع الحج بحارة لقيطة ----- 2489
# حي/المعابده الخانسه ----- 2492
# حي/المعابده بالششه ----- 2497
# حي/المعابده حارة لقيطة غرب شارع الحج ----- 2499
# حي/المعابده حى الغساله ----- 2501
# حي/المعابده دحلة الضبع غرب جبل النور ----- 2504
# حي/المعابده ريع ذاخر ----- 2507
# حي/المعيصم ----- 2511
# حي/المعيصم المعدل ----- 2524
# حي/المعيصم على يمين الذاهب الى الطائف ----- 2532
# حي/المعيصم للورش ----- 2535
# حي/المغمس ----- 2537
# حي/المقرح ----- 2543
# حي/الملاوى ----- 2546
# حي/الملاوى فى المعابده ----- 2548
# حي/الملاوى من محلة المعابدة ----- 2551
# حي/المنح بالعمرة ----- 2553
# حي/المنطقة الصناعية ----- 2555
# حي/المنطقة الصناعية بالتنعيم ----- 2558
# حي/المنطقة الصناعية بالتنعيم مخطط ب ----- 2564
# حي/النبعة ----- 2566
# حي/النبعة خلف المعهد المهنى ----- 2573
# حي/النبعة على يمين الذاهب الى وادى فاطمة ----- 2575
# حي/النبعة يمين الذاهب الى وادى فاطمة ----- 2582
# حي/النبعه خلف مركز التدريب المهنى ----- 2585
# حي/النخيل 2 ----- 2587
# حي/النزهة ----- 2595
# حي/النزهة النموذجى ----- 2599
# حي/النزهة النموذجى التكميلى ----- 2604
# حي/النسيم ----- 2608
# حي/النسيم اضافات ----- 2613
# حي/النسيم المعدل ----- 2621
# حي/النسيم المعدل المعتمد ----- 2632
# حي/النوارية ----- 2634
# حي/النوارية الشرقية ----- 2647
# حي/النوارية المعدل ----- 2651
# حي/النوارية المعدل رقم 8 ----- 2654
# حي/النوارية بالوسيعة ----- 2656
# حي/النوارية رقم 2 ----- 2658
# حي/الوسيق يسارالذاهب من مكه لجدة الطريق الجديد السريع ----- 2887
# حي/ام الجرفان من اعمال مكة ----- 2890
# حي/ام الجود ----- 2901
# حي/ام الجود على يسار الذاهب الى جده ----- 2903
# حي/ام الدرج ----- 2906
# حي/ام السدارة الواقعة على درب السلولى ----- 2911
# حي/ام القرى المعتمد ----- 2913
# حي/ام الكتاد ----- 2919
# حي/ام قضب على يمين الذاهب الى جده من الطريق الدائرى ا ----- 2932
# حي/امتداد البدر بكدى ----- 2934
# حي/امتداد البدربكدى ----- 2936
# حي/امتداد الرصيفة ----- 2939
# حي/امتداد الزاهر ----- 2941
# حي/امتداد الزاهر اضافات ----- 2945
# حي/امتداد الزاهر اضافات المعدل ----- 2947
# حي/امتداد الزهراء ----- 2953
# حي/امتداد الشرائع رقم 7 ----- 2955
# حي/امتداد الصرافية وادى سرف اللحيانية ----- 2959
# حي/امتداد الصناعية ----- 2968
# حي/امتداد الضفة الشرقية س د ----- 2971
# حي/امتداد الضفه الشرقيه س/ د ----- 2975
# حي/امتداد العسيلة للمنح ----- 2977
# حي/امتداد الفيحاء ----- 2980
# حي/امتداد المنطقة الصناعية ----- 2983
# حي/امتداد المنطقة الصناعية بالبحيرات رقم 2 ----- 2987
# حي/امتداد المنطقة الصناعية بالتنعيم ----- 2989
# حي/امتداد المنطقة الصناعية رقم 2 ----- 2993
# حي/امتداد المنطقة الصناعية رقم2 ----- 2995
# حي/امتداد المنطقه الصناعيه رقم 2 ----- 2999
# حي/امتداد ام الجود ----- 3002
# حي/امتداد حى الزاهر ----- 3015
# حي/امتداد مخطط ولى العهد رقم 1 ----- 3021
# حي/امتداد مخطط ولى العهد رقم 5 ----- 3031
# حي/امتداد مخطط ولى العهد للمنح رقم 5 ----- 3042
# حي/امتداد منح ابو مراغ ----- 3052
# حي/امتداد منح الشرائع 7 ----- 3057
# حي/امتداد منح الغسالة ----- 3059
# حي/امتداد ولى العهد ----- 3062
# حي/امتداد ولى العهد رقم 5 ----- 3065
# حي/بئر الغنم ----- 3077
# حي/بئر الغنم على يمين الذاهب للجعرانة ----- 3089
# حي/بئر الغنم على يمين الذاهب للجعرانة من النوارية ----- 3093
# حي/بئر بليلة من محلة جياد ----- 3099
# حي/بابى مرو ----- 3101
# حي/باشراحيل اضافات ----- 3103
# حي/بدر ----- 3105
# حي/بدر بكدى ----- 3108
# حي/بشم ----- 3110
# حي/بطحاء قريش ----- 3120
# حي/بطحاء قريش 1 ----- 3133
# حي/بطحاء قريش الاضافى ----- 3141
# حي/بطحاء قريش الايضافات ثلاثة ----- 3143
# حي/بطحاء قريش الجزء الثانى اضافات ----- 3156
# حي/بطحاء قريش المعتمد ----- 3162
# حي/بطحاء قريش المعدل ----- 3174
# حي/بطحاء قريش النموذجى ----- 3182
# حي/بطحاء قريش النموذجى المعدل ----- 3195
# حي/بطحاء قريش النموذجى رقم 2 ----- 3201
# حي/بطحاء قريش نموذجى ----- 3203
# حي/بطحاءقريش ----- 3215
# حي/بطريق اليمن بالقرب من الشوقيه ----- 3224
# حي/بمخطط جنوب المسفله رقم (2) ----- 3228
# حي/بمخطط ولى العهد رقم 8 ----- 3231
# حي/بن عمران ----- 3233
# حي/بين التنعيم والعمرة والمنطقة الصناعية ----- 3243
# حي/تخطيط أراضى فيصل بدر بالنزهة ----- 3245
# حي/تخطيط أرض العمرة معدل ----- 3252
# حي/تخطيط أرض بنى عمير الموقع رقم 1 المعدل ----- 3254
# حي/تخطيط اراضى العمرة المعدل ----- 3256
# حي/تخطيط اراضى فيصل بدر الواقعه بين المنجورة والهجيلة ----- 3258
# حي/تخطيط ارض العمرة المعدل ----- 3261
# حي/تخطيط ارض العمرة معدل ----- 3263
# حي/تخطيط منطقة حى المسفلة 11 جنوب 3 غرب 4 ----- 3265
# حي/تعديل المخطط العام لحى الفيصلية ----- 3267
# حي/تعديل المخطط العام لحى الفيصلية الششة المعتمد ----- 3269
# حي/تعديل جزء من مخطط بطحاء قريش اضافات 3 ----- 3272
# حي/تعديل مخطط المسفله11 جنوب 3 غرب 4 ----- 3275
# حي/تعديل واضافة جزء من مخطط جنوب العزيزية رقم 6 ----- 3280
# حي/تقسيم أراضى المطلق والجفرى بشارع الحج ----- 3282
# حي/تقسيم أرض الشيخ محمد صالح باشراحيل ----- 3291
# حي/تقسيم أرض العمرة ----- 3293
# حي/تقسيم أرض بن عمران ----- 3298
# حي/تقسيم أرض سمو الأمير أحمد بكدى ----- 3303
# حي/تقسيم ارض العمرة مخطط العمره العام ----- 3311
# حي/تقسيم ارض سمو الامير احمد بن عبدالعزيز ----- 3315
# حي/تقسيم قطع بمخطط العوالى ----- 3318
# حي/جبل الحفائر المطل على الطندباوى ----- 3329
# حي/جبل الحفائر من محلة حارة الباب ----- 3331
# حي/جبل الحفاير ----- 3334
# حي/جبل الحفاير من محلة الباب ----- 3337
# حي/جبل السبع البنات باجياد ----- 3339
# حي/جبل السيدة ----- 3341
# حي/جبل السيدة خديجة ----- 3348
# حي/جبل الشراشف ----- 3350
# حي/جبل الغراب بجرول ----- 3352
# حي/جبل الكعبة ----- 3354
# حي/جبل النور ----- 3356
# حي/جبل النور المعدل ----- 3364
# حي/جبل ثور ----- 3373
# حي/جبل خندمه شعب عامر ----- 3376
# حي/جبل دفان بمحلة السليمانية ----- 3379
# حي/جبل عمر ----- 3381
# حي/جبل قرمان بشعب عامر ----- 3385
# حي/جرول ----- 3387
# حي/جرول الحفاير ----- 3400
# حي/جرول الهنداوية ----- 3402
# حي/جرول بالعتيبية ----- 3405
# حي/جرول بمحلة الطندباوى ----- 3409
# حي/جرول جبل جحيشة ----- 3411
# حي/جرول خلف شارع المنصور ----- 3413
# حي/جرول شعبة الغاربة ----- 3415
# حي/جرول شعبة المغاربة ----- 3417
# حي/جزء المتبقى بارض الشوقيه بوادى ابراهيم علية السلام ----- 3419
# حي/جعرانة ----- 3429
# حي/جعرانة شرق الطريق المؤدى لمسجد جعرانة ----- 3437
# حي/جعرانه ----- 3440
# حي/جعرانه على يسار الذاهب لمسجد الجعرانه ----- 3453
# حي/جعرانه يسار الذاهب لمسجد الجعرانه من الشرائع ----- 3456
# حي/جنوب الحسينية ----- 3458
# حي/جنوب العزيزية ----- 3469
# حي/جنوب العزيزية الاضافات ----- 3482
# حي/جنوب العزيزية العوالى ----- 3490
# حي/جنوب العزيزية العوالى المعتمد ----- 3503
# حي/جنوب العزيزية المعدل ----- 3513
# حي/جنوب العزيزية رقم 1 ----- 3520
# حي/جنوب العزيزية رقم 1 العوالى ----- 3529
# حي/جنوب العزيزية على خط الاسفلت العام رقم واحد ----- 3540
# حي/جنوب العزيزية على خط الاسفلت رقم واحد ----- 3552
# حي/جنوب العزيزية مخطط الامير فواز ----- 3558
# حي/جنوب العزيزيه ----- 3562
# حي/جنوب المسفلة جزئى 10و11 ----- 3575
# حي/جنوب المسفلة جزائى 10/ 11 ----- 3585
# حي/جنوب المسفلة رقم 10/ 11 ----- 3588
# حي/جنوب المسفلة رقم 2 ----- 3590
# حي/جنوب المسفلة رقم 2 الكعكية ----- 3602
# حي/جنوب المسفلة رقم واحد ----- 3613
# حي/جنوب المسفلة رقم واحد المعتمد ----- 3615
# حي/جنوب خط الخواجات شرق طريق الليث بأم الراكة ----- 3617
# حي/جنوب خط الخواجات غرب جبل التناعيم بالدحال السود ----- 3619
# حي/جنوب محطة الهاشم يمين الذاهب الى الطائف طريق السيل ----- 3622
# حي/جنوب مكة المكرمة حارة دعد ----- 3625
# حي/جياد ----- 3627
# حي/حارة اكلب من محلة المعابدة ----- 3630
# حي/حارة الباب بعلو جبل الحفائر ----- 3632
# حي/حارة الحروب غرب العمرة التنعيم ----- 3634
# حي/حارة الدعاجين بحارة المعابدة ----- 3636
# حي/حارة خميم خلف مواقف سيارات حجاج البر بكدى ----- 3638
# حي/حداء على يمين الذاهب الى جده ----- 3642
# حي/حوض البقر بحى العزيزية محبس الجن ----- 3645
# حي/حى الزهور جنوب مخطط الشوقية ----- 3647
# حي/حى العزيزية ----- 3649
# حي/حى العزيزية الضفة الغربية ----- 3652
# حي/حى المسرات يمين الذاهب الى مسجد الجعرانة ----- 3655
# حي/خلف المدرسة بالعزيزية ----- 3657
# حي/خلف شارع المنصور ----- 3661
# حي/خمسة للورش ----- 3664
# حي/خندمة ----- 3666
# حي/دحلة الضبع غرب جبل النور ----- 3668
# حي/دحلة محبس الجن المعدل ----- 3670
# حي/درب جدة القديم امتداد حى الزاهر ----- 3672
# حي/درب حدة القديم امتداد حى الزاهر ----- 3675
# حي/درة السبهانى ----- 3677
# حي/دقم الوبر ----- 3686
# حي/ربوة الشرائع ----- 3688
# حي/ربوة كدى ----- 3690
# حي/ربوة كدى بالمسفلة ----- 3702
# حي/ربوة مكة ----- 3706
# حي/ربوة مكه ----- 3714
# حي/رقم خمسة المعدل للورش ----- 3727
# حي/روابى جياد المعدل ----- 3733
# حي/روابى كدى ----- 3736
# حي/ريع الحجون السليمانية ----- 3739
# حي/ريع الكحل ----- 3742
# حي/ريع المسكين من محلة المعابدة ----- 3745
# حي/ريع بخش ----- 3747
# حي/ريع بخش باجياد ----- 3755
# حي/ريع ذاخر ----- 3759
# حي/ريع ذاخر بالمعابدة ----- 3763
# حي/ريع ذاخر على يمين الذاهب لشارع الحج ----- 3766
# حي/محلة البحيرات على يسار الذاهب الى وادى فاطمة ----- 4368
# حي/محلة الحفائر بجرول ----- 4371
# حي/محلة الحفائر من محلة حارة الباب ----- 4373
# حي/محلة الحفاير حارة الباب ----- 4375
# حي/محلة الزهراء مما يلى الهنداوية ----- 4377
# حي/محلة الطندباوى ----- 4379
# حي/محلة الطندباوى شارع المنصور ----- 4381
# حي/محلة العزيزية الضفة الغربية ----- 4383
# حي/محلة الفجيج ----- 4385
# حي/محلة المسفلة الكدوة القديمة ----- 4387
# حي/محلة المسفلة خلف قهوة الخنكار ----- 4389
# حي/محلة المسفلة كدى ----- 4391
# حي/محلة المسفلة كدى جبل ابو شدادين ----- 4393
# حي/محلة المعابدة الخانسة ----- 4395
# حي/محلة المعابدة بالروضة ----- 4397
# حي/محلة المعابدة ريع ذاخر ----- 4408
# حي/محلة المعابدة شارع الحج ----- 4410
# حي/محلة المعابدة شرق شارع الحج ----- 4412
# حي/محلة المغمس ----- 4414
# حي/محلة النبعة على يمين الذاهب لوادى فاطمة ----- 4416
# حي/محلة النبعه ----- 4418
# حي/محلة الهنداوية ----- 4420
# حي/محلة الهنداوية بجبل الغراب ----- 4424
# حي/محلة ام الجود على يسار الذاهب الى جده ----- 4426
# حي/محلة جرول ----- 4428
# حي/محلة جرول بالحفائر ----- 4430
# حي/محلة جرول بالطندباوى ----- 4432
# حي/محلة جرول خلف شارع المنصور من الجهة الغربية ----- 4435
# حي/محلة شارع المنصور خلف الهلال الاحمر ----- 4437
# حي/محلة وادى عرعر ----- 4439
# حي/محله شرفه الخلاص بام الدخان ----- 4444
# حي/محمد سليم اللحيانى العمرة الجديده ----- 4446
# حي/مخطط 3 بالعمرة الجديد ودرجتها الثالثة ----- 4448
# حي/مخطط أبو مراغ 3 ----- 4451
# حي/مخطط أبو مراغ رقم 2 ----- 4457
# حي/مخطط أبى مراغ ----- 4461
# حي/مخطط أرض التوانك بالنزهة ----- 4470
# حي/مخطط أم القرى ----- 4473
# حي/مخطط أم الكتاد ----- 4486
# حي/مخطط أمتداد المنطقة الصناعية بحى التنعيم ----- 4497
# حي/مخطط اراضى فيصل بدر ----- 4500
# حي/مخطط ارض العمره المعدل ----- 4502
# حي/مخطط الأمير أحمد بالرصيفة ----- 4504
# حي/مخطط الأمير أحمد بالرصيفة المعدل ----- 4511
# حي/مخطط الأمير عبدالله الفيصل ----- 4517
# حي/مخطط الأمير عبدالله الفيصل الششه ----- 4525
# حي/مخطط الامير احمد بن عبدالعزيز ----- 4532
# حي/مخطط البحيرات ----- 4534
# حي/مخطط البدر بكدى ----- 4542
# حي/مخطط البوابة رقم 3 ----- 4549
# حي/مخطط البوابة رقم 6 ----- 4562
# حي/مخطط البوابة رقم 7 ----- 4574
# حي/مخطط البوابة رقم 8 ----- 4581
# حي/مخطط البوابة رقم 9 ----- 4592
# حي/مخطط البواية رقم8 ----- 4604
# حي/مخطط التنعيم رقم 4 ----- 4607
# حي/مخطط الحمراء الاضافى المعدل ----- 4611
# حي/مخطط الخالدية ----- 4613
# حي/مخطط الخالدية المعدل رقم 1 ----- 4620
# حي/مخطط الخالدية بجزئية رقم واحد ورقم اثنين ----- 4627
# حي/مخطط الخالدية جزء رقم واحد ----- 4630
# حي/مخطط الخضراء ----- 4634
# حي/مخطط الخضراء المعدل ----- 4637
# حي/مخطط الراشدية 2 مجاز ----- 4650
# حي/مخطط الراشديه المعدل ----- 4658
# حي/مخطط الربوه ----- 4670
# حي/مخطط الرصيفة ----- 4673
# حي/مخطط الريان ----- 4677
# حي/مخطط الزاهر ----- 4690
# حي/مخطط السلولى المرحله الأولى المعتمد ----- 4692
# حي/مخطط الشرائع 15 للمنح ----- 4695
# حي/مخطط الشرائع 4 ----- 4702
# حي/مخطط الشرائع 5 ----- 4715
# حي/مخطط الشرائع رقم 1 ----- 4725
# حي/مخطط الشرائع رقم 13 ----- 4738
# حي/مخطط الشرائع رقم 2 ----- 4751
# حي/مخطط الشرائع رقم 3 ----- 4753
# حي/مخطط الشرائع رقم 4 ----- 4766
# حي/مخطط الشرائع رقم 5 ----- 4778
# حي/مخطط الشرائع رقم 9 اضافات ----- 4780
# حي/مخطط الشرائع رقم سبعة المعتمد ----- 4790
# حي/مخطط الشهداء السكنى النموذجى ----- 4793
# حي/مخطط الشوقية ----- 4799
# حي/مخطط الصبان المعدل ----- 4812
# حي/مخطط الضفة الشرقية ج بالعزيزية ----- 4816
# حي/مخطط الضفة الغربية تقسيم (4) ----- 4821
# حي/مخطط الضفه الغربيه تقسيم (1) ----- 4824
# حي/مخطط الضفه الغربيه رقم 4حى العزيزيه ----- 4826
# حي/مخطط العدل ----- 4829
# حي/مخطط العسيلة ----- 4831
# حي/مخطط العسيله ----- 4844
# حي/مخطط العمرة 3 ----- 4852
# حي/مخطط العمرة المعدل رقم 8 ----- 4854
# حي/مخطط العمرة النموذجى رقم ثمانيه ----- 4864
# حي/مخطط العمرة رقم 2 ----- 4866
# حي/مخطط العمرة رقم 3 ----- 4873
# حي/مخطط العمرة رقم 6 ----- 4882
# حي/مخطط العمرة رقم 8 ----- 4895
# حي/مخطط العمرة رقم 9 زهرة العمرة ----- 4906
# حي/مخطط العمره الجديده ----- 4916
# حي/مخطط العمره المعدل ----- 4928
# حي/مخطط الغسالة رقم 1 المعدل ----- 4934
# حي/مخطط الفيحاء ----- 4938
# حي/مخطط الفيحاء المعدل ----- 4948
# حي/مخطط الكيلو الثانى ----- 4956
# حي/مخطط المسفلة ----- 4958
# حي/مخطط المسفلة 11/10 ----- 4966
# حي/مخطط المسفلة التجميعى والمعدل المروه ----- 4969
# حي/مخطط المسفلة الواقع فى جزئى 10 و11 ----- 4974
# حي/مخطط المسفلة رقم 12 ----- 4987
# حي/مخطط المسفلة رقم 4 ----- 5000
# حي/مخطط المشمس ----- 5013
# حي/مخطط المعابدة رقم 6 ----- 5021
# حي/مخطط المعيصم المعتمد ----- 5028
# حي/مخطط المعيصم المعدل ----- 5039
# حي/مخطط المنح العمرة خلف شراحيل ----- 5041
# حي/مخطط المنح بالعمرة اضافات المعدل ----- 5044
# حي/مخطط المنح شارع الحج المعدل ----- 5049
# حي/مخطط النخيل ----- 5051
# حي/مخطط النزهة النموذجى التكميلى ----- 5064
# حي/مخطط النور النموذجى للورش المعتمد ----- 5071
# حي/مخطط الورش والمستودعات بام الجود ----- 5075
# حي/مخطط امتداد أم الجود منح ----- 5079
# حي/مخطط امتداد الخالدية ----- 5081
# حي/مخطط امتداد الصرافية ----- 5083
# حي/مخطط امتداد المنطقة 3 ----- 5088
# حي/مخطط امتداد المنطقة الصناعية أبو كلاب ----- 5091
# حي/مخطط امتداد المنطقة الصناعية بالعمرة ----- 5093
# حي/مخطط امتداد المنطقة الصناعية بالعمرة 2 ----- 5095
# حي/مخطط امتداد المنطقة الصناعية رقم 2 ----- 5102
# حي/مخطط امتداد المنطقة الصناعية رقم 2 أبو كلاب ----- 5105
# حي/مخطط امتداد المنطقه الصناعيه رقم 3 ابو كلاب ----- 5107
# حي/مخطط امتداد منح أبى مراغ ----- 5109
# حي/مخطط ايضافات فيصل بدر ----- 5113
# حي/مخطط بشم شارع الحج ----- 5116
# حي/مخطط بطحاء قريش ----- 5118
# حي/مخطط بطحاء قريش اضافات 2 ----- 5131
# حي/مخطط بطحاء قريش النموذجى ----- 5133
# حي/مخطط بطحاء قريش النموذجى 2 ----- 5136
# حي/مخطط تخطيط ارض العمرة معدل ----- 5146
# حي/مخطط تقسيم أرض العمرة ----- 5148
# حي/مخطط جبل السيده ----- 5152
# حي/مخطط جنوب العزيزية ----- 5154
# حي/مخطط جنوب العزيزيه المعدل ----- 5162
# حي/مخطط جنوب المسفلة 1 ----- 5164
# حي/مخطط جنوب المسفلة رقم (2) منح ----- 5171
# حي/مخطط جنوب المسفلة رقم 2 المعدل ----- 5173
# حي/مخطط حامد السفيانى رقم 1 ----- 5175
# حي/مخطط حامد السفيانى رقم 2 ----- 5177
# حي/مخطط حامد السفيانى رقم 3 ----- 5181
# حي/مخطط حامد السفيانى رقم 3 اضافات ----- 5185
# حي/مخطط حامد السفيانى رقم 4 ----- 5189
# حي/مخطط حراء ----- 5192
# حي/مخطط حى التنعيم رقم 4 ----- 5199
# حي/مخطط حى الحمراء ----- 5206
# حي/مخطط حى السلامة اضافات ----- 5217
# حي/مخطط حى المسفلة رقم 10 المعدل ----- 5221
# حي/مخطط خارج مخطط الخضراء ----- 5228
# حي/مخطط سليمان الحمد ----- 5230
# حي/مخطط شارع الحج ----- 5234
# حي/مخطط غرب حى العزيزية ----- 5238
# حي/مخطط فيصل بدر المعدل ----- 5242
# حي/مخطط مصانع الأجور ----- 5250
# حي/مخطط منح الأجور بالعمرة 9 ----- 5252
# حي/مخطط منح الراشدية 2 المجاز ----- 5254
# حي/مخطط منح الشرائح رقم 12 المعدل ----- 5257
# حي/مخطط منح الشرائع رقم 10 المعدل ----- 5260
# حي/مخطط منح الشرائع رقم 12 المعدل ----- 5266
# حي/مخطط منح العمرة 12 ----- 5274
# حي/مخطط منح النوارية رقم 2 ----- 5282
# حي/مخطط نبع الخير ----- 5286
# حي/مخطط وادى السلولى المعدل المرحلة الأولى ----- 5291
# حي/مخطط وادى بنى عمير ----- 5297
# حي/مخطط وادى جليل ----- 5299
# حي/وادى ضجة يمين الذاهب الى الطائف بطريق الهدا ----- 5730
# حي/وادى ضيم ----- 5732
# حي/وادى ضيم جنوب خط الخواجات ----- 5735
# حي/وادى عرعر يمين الذاهب الى الطائف ----- 5740
# حي/وادى علق ----- 5743
# حي/وادى فخ ----- 5747
# حي/وادى مغيث ----- 5749
# حي/وادى ملكان ----- 5751
# حي/وادى نعمان ----- 5754
# حي/وادى ياج شمال مكة المكرمة ----- 5762
# حي/والى العهد رقم 3 ----- 5764
# حي/ولى العهد 4 ----- 5777
# حي/ولى العهد 7 ----- 5790
# حي/ولى العهد 8 ----- 5803
# حي/ولى العهد 8 المعدل ----- 5815
# حي/ولى العهد رقم 1 ----- 5820
# حي/ولى العهد رقم 10 ----- 5833
# حي/ولى العهد رقم 2 ----- 5845
# حي/ولى العهد رقم 3 ----- 5858
# حي/ولى العهد رقم 4 ----- 5871
# حي/ولى العهد رقم 5 ----- 5884
# حي/ولى العهد رقم 6 ----- 5897
# حي/ولى العهد رقم 6 المعدل ----- 5910
# حي/ولى العهد رقم 7 ----- 5912
# حي/ولى العهد رقم 7 المعدل ----- 5925
# حي/ولى العهد رقم 7 للمنح ----- 5935
# حي/ولى العهد رقم 8 ----- 5944
# حي/ولى العهد رقم 8 المعدل ----- 5957
# حي/ولى العهد رقم 9 ----- 5969
# حي/ولى العهد للمنح 5 ----- 5972
# حي/ولى العهد للمنح رقم 1 ----- 5974
# حي/ولى العهد للمنح رقم 2 ----- 5980
# حي/ولى العهد للمنح رقم 3 ----- 5982
# حي/ولى العهد للمنح رقم 4 ----- 5987
# حي/ولى العهد للمنح رقم 5 ----- 5992
# حي/ولى العهد للمنح رقم 5 المعدل ----- 6001
# حي/ولى العهد للمنح رقم 6 ----- 6007
# حي/ولى العهد للمنح رقم 7 المعدل ----- 6009
# حي/ولى العهد للمنح رقم 8 ----- 6013
# حي/ولى العهد للمنح رقم2 ----- 6020
# حي/يمين الذاهب الى الليث بمكة المكرمة بطريق الساحل ----- 6027

# %%
# number of district
len(list_redundant)
# Out:
# 1147

# %% [markdown]
# ## Defining some repeated code

# %%
def year_df(df, yr = "2018", lst = [0,1,2,3,4]):
    """
    input: orignal dataset , set the year of data extracted , list of columns the information to be extracted from
    rturn: dataframe with column names year, month, realstate_cls, realstate_type, price_riyals, area_m2, no_deals
    """
    # select the columns from orignal dataset
    df = df.iloc[:, lst]
    
    # Changing columns name with index number
    df = df.rename(
        columns ={
            df.columns[2]: 'price_riyals',
            df.columns[3]: 'area_m2',
            df.columns[4]: 'no_deals'
        })
    
    # set the year for data extracted
    df.insert(loc = 0, column= 'year', value= yr)
    
    # due to removing some row
    df.reset_index(inplace = True)
    
    # returning the processed data 
    return df.drop(df.columns[0], axis=1)

# %% [markdown]
# ### 1- Get 2018 data from orignal database

# %%
df = year_df(df_Makkah, yr = "2018", lst = [0,1,2,3,4])
df.head(20)
# Out:
#     year                                              month         district  \
# 0   2018    المؤشر العقاري للأحياء بمدينة مكة المكرمة في...
# 1   2018                                                NaN
# 2   2018                                            المدينة
# 3   2018                      حالة العملية(معتمدة/ملغية/..)
# 4   2018                                                NaN
# 5   2018                                                NaN
# 6   2018                                                NaN
# 7   2018                                            الأحياء
# 8   2018                                       حي/1/ 20/ 27
# 9   2018                                              يناير     حي/1/ 20/ 27
# 10  2018                                              يوليو     حي/1/ 20/ 27
# 11  2018                                             اوغسطس     حي/1/ 20/ 27
# 12  2018                                             نوفمبر     حي/1/ 20/ 27
# 13  2018                                    حي/1/ 29/ 10/ أ
# 14  2018                                              يناير  حي/1/ 29/ 10/ أ
# 15  2018                                        حي/1/ 32/ 1
# 16  2018                                               مارس      حي/1/ 32/ 1
# 17  2018                                    حي/1/ 32/ 16/ أ
# 18  2018                                             اوغسطس  حي/1/ 32/ 16/ أ
# 19  2018                          حي/45 بطحاء قريش النموذجى
#
#              price_riyals                area_m2     no_deals
# 0                     NaN                    NaN          NaN
# 1                     NaN                    NaN          NaN
# 2             مكة المكرمة                    NaN          NaN
# 3                  معتمدة                    NaN          NaN
# 4                     NaN                    NaN          NaN
# 5                     NaN                    NaN          NaN
# 6                    2018                    NaN          NaN
# 7   السعر بالريال السعودي  المساحة بالمتر المربع  عدد الصفقات
# 8                  550000                    550            1
# 9                     NaN                    NaN          NaN
# 10                    NaN                    NaN          NaN
# 11                    NaN                    NaN          NaN
# 12                 550000                    550            1
# 13                    NaN                    NaN          NaN
# 14                    NaN                    NaN          NaN
# 15                    NaN                    NaN          NaN
# 16                    NaN                    NaN          NaN
# 17                    NaN                    NaN          NaN
# 18                    NaN                    NaN          NaN
# 19                2380000                 691.45            4

# %% [markdown]
# ### 2-Get 2019 data from orignal database

# %%
df_2019 = year_df(df_Makkah, yr = "2019", lst = [0,1,5,6,7])
df_2019.head(20)
# Out:
#     year                                              month         district  \
# 0   2019    المؤشر العقاري للأحياء بمدينة مكة المكرمة في...
# 1   2019                                                NaN
# 2   2019                                            المدينة
# 3   2019                      حالة العملية(معتمدة/ملغية/..)
# 4   2019                                                NaN
# 5   2019                                                NaN
# 6   2019                                                NaN
# 7   2019                                            الأحياء
# 8   2019                                       حي/1/ 20/ 27
# 9   2019                                              يناير     حي/1/ 20/ 27
# 10  2019                                              يوليو     حي/1/ 20/ 27
# 11  2019                                             اوغسطس     حي/1/ 20/ 27
# 12  2019                                             نوفمبر     حي/1/ 20/ 27
# 13  2019                                    حي/1/ 29/ 10/ أ
# 14  2019                                              يناير  حي/1/ 29/ 10/ أ
# 15  2019                                        حي/1/ 32/ 1
# 16  2019                                               مارس      حي/1/ 32/ 1
# 17  2019                                    حي/1/ 32/ 16/ أ
# 18  2019                                             اوغسطس  حي/1/ 32/ 16/ أ
# 19  2019                          حي/45 بطحاء قريش النموذجى
#
#              price_riyals                area_m2     no_deals
# 0                     NaN                    NaN          NaN
# 1                     NaN                    NaN          NaN
# 2                     NaN                    NaN          NaN
# 3                     NaN                    NaN          NaN
# 4                     NaN                    NaN          NaN
# 5                     NaN                    NaN          NaN
# 6                    2019                    NaN          NaN
# 7   السعر بالريال السعودي  المساحة بالمتر المربع  عدد الصفقات
# 8                 1670000                    844            3
# 9                  540000                    172            1
# 10                 530000                    172            1
# 11                 600000                    500            1
# 12                    NaN                    NaN          NaN
# 13                    NaN                    NaN          NaN
# 14                    NaN                    NaN          NaN
# 15                    NaN                    NaN          NaN
# 16                    NaN                    NaN          NaN
# 17                    NaN                    NaN          NaN
# 18                    NaN                    NaN          NaN
# 19                    NaN                    NaN          NaN

# %% [markdown]
# ### 3-Get 2020 data from orignal database

# %%
df_2020 = year_df(df_Makkah, yr = "2020", lst = [0,1,8,9,10])
df_2020.head(20)
# Out:
#     year                                              month         district  \
# 0   2020    المؤشر العقاري للأحياء بمدينة مكة المكرمة في...
# 1   2020                                                NaN
# 2   2020                                            المدينة
# 3   2020                      حالة العملية(معتمدة/ملغية/..)
# 4   2020                                                NaN
# 5   2020                                                NaN
# 6   2020                                                NaN
# 7   2020                                            الأحياء
# 8   2020                                       حي/1/ 20/ 27
# 9   2020                                              يناير     حي/1/ 20/ 27
# 10  2020                                              يوليو     حي/1/ 20/ 27
# 11  2020                                             اوغسطس     حي/1/ 20/ 27
# 12  2020                                             نوفمبر     حي/1/ 20/ 27
# 13  2020                                    حي/1/ 29/ 10/ أ
# 14  2020                                              يناير  حي/1/ 29/ 10/ أ
# 15  2020                                        حي/1/ 32/ 1
# 16  2020                                               مارس      حي/1/ 32/ 1
# 17  2020                                    حي/1/ 32/ 16/ أ
# 18  2020                                             اوغسطس  حي/1/ 32/ 16/ أ
# 19  2020                          حي/45 بطحاء قريش النموذجى
#
#              price_riyals                area_m2     no_deals
# 0                     NaN                    NaN          NaN
# 1                     NaN                    NaN          NaN
# 2                     NaN                    NaN          NaN
# 3                     NaN                    NaN          NaN
# 4                     NaN                    NaN          NaN
# 5                     NaN                    NaN          NaN
# 6                    2020                    NaN          NaN
# 7   السعر بالريال السعودي  المساحة بالمتر المربع  عدد الصفقات
# 8                 1132313                    460            1
# 9                     NaN                    NaN          NaN
# 10                1132313                    460            1
# 11                    NaN                    NaN          NaN
# 12                    NaN                    NaN          NaN
# 13                1550000                  612.5            1
# 14                1550000                  612.5            1
# 15                    NaN                    NaN          NaN
# 16                    NaN                    NaN          NaN
# 17                 300000                    600            1
# 18                 300000                    600            1
# 19                1390000                 368.91            2

# %% [markdown]
# ### 4-Get 2021 data from orignal database

# %%
df_2021 = year_df(df_Makkah, yr = "2021", lst = [0,1,11,12,13])
df_2021.head(20)
# Out:
#     year                                              month         district  \
# 0   2021    المؤشر العقاري للأحياء بمدينة مكة المكرمة في...
# 1   2021                                                NaN
# 2   2021                                            المدينة
# 3   2021                      حالة العملية(معتمدة/ملغية/..)
# 4   2021                                                NaN
# 5   2021                                                NaN
# 6   2021                                                NaN
# 7   2021                                            الأحياء
# 8   2021                                       حي/1/ 20/ 27
# 9   2021                                              يناير     حي/1/ 20/ 27
# 10  2021                                              يوليو     حي/1/ 20/ 27
# 11  2021                                             اوغسطس     حي/1/ 20/ 27
# 12  2021                                             نوفمبر     حي/1/ 20/ 27
# 13  2021                                    حي/1/ 29/ 10/ أ
# 14  2021                                              يناير  حي/1/ 29/ 10/ أ
# 15  2021                                        حي/1/ 32/ 1
# 16  2021                                               مارس      حي/1/ 32/ 1
# 17  2021                                    حي/1/ 32/ 16/ أ
# 18  2021                                             اوغسطس  حي/1/ 32/ 16/ أ
# 19  2021                          حي/45 بطحاء قريش النموذجى
#
#              price_riyals                area_m2     no_deals
# 0                     NaN                    NaN          NaN
# 1                     NaN                    NaN          NaN
# 2                     NaN                    NaN          NaN
# 3                     NaN                    NaN          NaN
# 4                     NaN                    NaN          NaN
# 5                     NaN                    NaN          NaN
# 6                    2021                    NaN          NaN
# 7   السعر بالريال السعودي  المساحة بالمتر المربع  عدد الصفقات
# 8                     NaN                    NaN          NaN
# 9                     NaN                    NaN          NaN
# 10                    NaN                    NaN          NaN
# 11                    NaN                    NaN          NaN
# 12                    NaN                    NaN          NaN
# 13                1700000                  612.5            1
# 14                1700000                  612.5            1
# 15                 800000                  721.8            1
# 16                 800000                  721.8            1
# 17                    NaN                    NaN          NaN
# 18                    NaN                    NaN          NaN
# 19                    NaN                    NaN          NaN

# %% [markdown]
# ### join all extract data for years 2018 2019 2020 2021

# %%
df = df.append(df_2019)
df = df.append(df_2020)
df = df.append(df_2021)

# %%
# check the size of new data
df.shape
# Out:
# (24116, 6)

# %%
# check for first five rows
df.head()
# Out:
#    year                                              month district  \
# 0  2018    المؤشر العقاري للأحياء بمدينة مكة المكرمة في...
# 1  2018                                                NaN
# 2  2018                                            المدينة
# 3  2018                      حالة العملية(معتمدة/ملغية/..)
# 4  2018                                                NaN
#
#   price_riyals area_m2 no_deals
# 0          NaN     NaN      NaN
# 1          NaN     NaN      NaN
# 2  مكة المكرمة     NaN      NaN
# 3       معتمدة     NaN      NaN
# 4          NaN     NaN      NaN

# %%
# current statistics of data 
df.describe(include="all")
# Out:
#          year   month district  price_riyals  area_m2  no_deals
# count   24116   24100    24116         10710    10704     10704
# unique      4    1163     1148          4292     7009       142
# top      2018  فبراير                 100000      400         1
# freq     6029    1888     4620           266      357      5245

# %%
# current datatype of data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24116 entries, 0 to 6028
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          24116 non-null  object
#  1   month         24100 non-null  object
#  2   district      24116 non-null  object
#  3   price_riyals  10710 non-null  object
#  4   area_m2       10704 non-null  object
#  5   no_deals      10704 non-null  object
# dtypes: object(6)
# memory usage: 1.3+ MB

# %% [markdown]
# ## Now clean redundant data and empty cells

# %%
# save redundant data for future use
df_redundant = df[df.index.isin(list_redundant)]
df_redundant
# Out:
#       year                                              month district  \
# 8     2018                                       حي/1/ 20/ 27
# 13    2018                                    حي/1/ 29/ 10/ أ
# 15    2018                                        حي/1/ 32/ 1
# 17    2018                                    حي/1/ 32/ 16/ أ
# 19    2018                          حي/45 بطحاء قريش النموذجى
# ...    ...                                                ...      ...
# 6007  2021                           حي/ولى العهد للمنح رقم 6
# 6009  2021                    حي/ولى العهد للمنح رقم 7 المعدل
# 6013  2021                           حي/ولى العهد للمنح رقم 8
# 6020  2021                            حي/ولى العهد للمنح رقم2
# 6027  2021  حي/يمين الذاهب الى الليث بمكة المكرمة بطريق ال...
#
#      price_riyals  area_m2 no_deals
# 8          550000      550        1
# 13            NaN      NaN      NaN
# 15            NaN      NaN      NaN
# 17            NaN      NaN      NaN
# 19        2380000   691.45        4
# ...           ...      ...      ...
# 6007       620000      594        2
# 6009       300000      280        1
# 6013      1880000  2562.28        7
# 6020      1600000  1495.09        3
# 6027          NaN      NaN      NaN
#
# [4588 rows x 6 columns]

# %%
# get cleaned data 
df = df[df.month.isin(months_names)]
df
# Out:
#       year   month                                           district  \
# 9     2018   يناير                                       حي/1/ 20/ 27
# 10    2018   يوليو                                       حي/1/ 20/ 27
# 11    2018  اوغسطس                                       حي/1/ 20/ 27
# 12    2018  نوفمبر                                       حي/1/ 20/ 27
# 14    2018   يناير                                    حي/1/ 29/ 10/ أ
# ...    ...     ...                                                ...
# 6023  2021   ابريل                            حي/ولى العهد للمنح رقم2
# 6024  2021  سبتمبر                            حي/ولى العهد للمنح رقم2
# 6025  2021  نوفمبر                            حي/ولى العهد للمنح رقم2
# 6026  2021  ديسمبر                            حي/ولى العهد للمنح رقم2
# 6028  2021   يوليو  حي/يمين الذاهب الى الليث بمكة المكرمة بطريق ال...
#
#      price_riyals area_m2 no_deals
# 9             NaN     NaN      NaN
# 10            NaN     NaN      NaN
# 11            NaN     NaN      NaN
# 12         550000     550        1
# 14            NaN     NaN      NaN
# ...           ...     ...      ...
# 6023       900000  880.09        2
# 6024          NaN     NaN      NaN
# 6025          NaN     NaN      NaN
# 6026          NaN     NaN      NaN
# 6028          NaN     NaN      NaN
#
# [19496 rows x 6 columns]

# %% [markdown]
# ### Convert column to appropriate data type

# %%
# السعر بالريال السعودي
# fill none value with zeros
df['price_riyals'] = df['price_riyals'].fillna(0).astype(np.int64)

# المساحة بالمتر المربع
# fill none value with zeros
df['area_m2'] = df['area_m2'].fillna(0.0).astype(float)

# عدد الصفقات
# fill none value with zeros
df['no_deals'] = df['no_deals'].fillna(0).astype(int)

# %% [markdown]
# ### Adding addtional information to database

# %%
# adding city name
df.insert(loc = 2, column= 'city', value= df_city_name)

# adding تصنيف العقار
df.insert(loc = 3, column= 'realstate_cls', value= '')

# adding نوع العقار
df.insert(loc = 4, column= 'realstate_type', value= '')

# adding حالة العملية(معتمدة/ملغية/..)
df.insert(loc = 7, column= 'status', value = df_status)

# fill nan in string with empty 
df.fillna('', inplace=True)

# %% [markdown]
# ### Explore modified dataset

# %%
# check for first five rows
df.head()
# Out:
#     year   month         city realstate_cls realstate_type         district  \
# 9   2018   يناير  مكة المكرمة                                  حي/1/ 20/ 27
# 10  2018   يوليو  مكة المكرمة                                  حي/1/ 20/ 27
# 11  2018  اوغسطس  مكة المكرمة                                  حي/1/ 20/ 27
# 12  2018  نوفمبر  مكة المكرمة                                  حي/1/ 20/ 27
# 14  2018   يناير  مكة المكرمة                               حي/1/ 29/ 10/ أ
#
#     price_riyals  status  area_m2  no_deals
# 9              0  معتمدة      0.0         0
# 10             0  معتمدة      0.0         0
# 11             0  معتمدة      0.0         0
# 12        550000  معتمدة    550.0         1
# 14             0  معتمدة      0.0         0

# %%
# current datatype of data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19496 entries, 9 to 6028
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            19496 non-null  object
#  1   month           19496 non-null  object
#  2   city            19496 non-null  object
#  3   realstate_cls   19496 non-null  object
#  4   realstate_type  19496 non-null  object
#  5   district        19496 non-null  object
#  6   price_riyals    19496 non-null  int64
#  7   status          19496 non-null  object
#  8   area_m2         19496 non-null  float64
#  9   no_deals        19496 non-null  int32
# dtypes: float64(1), int32(1), int64(1), object(7)
# memory usage: 1.6+ MB

# %%
# check size of data
df.shape
# Out:
# (19496, 10)

# %% [markdown]
# ### Rearranging dataset in final shape
# #### Complete information with missing values

# %%
df_names = [
    "year",          # العام
    "month",         # الشهر
    "city",          # المدينة
    "district",      # الأحياء
    "price_riyals",  # السعر بالريال السعودي
    "area_m2",       # المساحة بالمتر المربع
    "no_deals",      # عدد الصفقات
    "status",        # حالة العملية(معتمدة/ملغية/..)
    "realstate_cls", # تصنيف العقار
    "realstate_type" # نوع العقار
]

# %%
# Rearranging columns orders
df = df[df_names]

# %%
# check the modification
df.head()
# Out:
#     year   month         city         district  price_riyals  area_m2  \
# 9   2018   يناير  مكة المكرمة     حي/1/ 20/ 27             0      0.0
# 10  2018   يوليو  مكة المكرمة     حي/1/ 20/ 27             0      0.0
# 11  2018  اوغسطس  مكة المكرمة     حي/1/ 20/ 27             0      0.0
# 12  2018  نوفمبر  مكة المكرمة     حي/1/ 20/ 27        550000    550.0
# 14  2018   يناير  مكة المكرمة  حي/1/ 29/ 10/ أ             0      0.0
#
#     no_deals  status realstate_cls realstate_type
# 9          0  معتمدة
# 10         0  معتمدة
# 11         0  معتمدة
# 12         1  معتمدة
# 14         0  معتمدة

# %%
# check the datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19496 entries, 9 to 6028
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            19496 non-null  object
#  1   month           19496 non-null  object
#  2   city            19496 non-null  object
#  3   district        19496 non-null  object
#  4   price_riyals    19496 non-null  int64
#  5   area_m2         19496 non-null  float64
#  6   no_deals        19496 non-null  int32
#  7   status          19496 non-null  object
#  8   realstate_cls   19496 non-null  object
#  9   realstate_type  19496 non-null  object
# dtypes: float64(1), int32(1), int64(1), object(7)
# memory usage: 1.6+ MB

# %% [markdown]
# ### Rearranging dataset in final shape
# #### information with no missing values

# %%
# if price equal to zero and
#    area equal to zero and
#    number of deals equal to zero then drop those rows
df_m = df[(df.price_riyals > 0) & (df.area_m2 > 0) & (df.no_deals > 0)]

# %%
# check the modification
df_m.head()
# Out:
#     year   month         city                   district  price_riyals  \
# 12  2018  نوفمبر  مكة المكرمة               حي/1/ 20/ 27        550000
# 21  2018  فبراير  مكة المكرمة  حي/45 بطحاء قريش النموذجى        700000
# 22  2018    مارس  مكة المكرمة  حي/45 بطحاء قريش النموذجى        300000
# 23  2018   ابريل  مكة المكرمة  حي/45 بطحاء قريش النموذجى       1380000
# 25  2018  فبراير  مكة المكرمة                حي/أبو مراغ        550000
#
#     area_m2  no_deals  status realstate_cls realstate_type
# 12   550.00         1  معتمدة
# 21   161.82         1  معتمدة
# 22   135.33         1  معتمدة
# 23   394.30         2  معتمدة
# 25   394.00         1  معتمدة

# %%
# if any other columns has missing values drop this column
#df_m = df_m.dropna(axis='columns')

# %%
# check the modification
df_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8152 entries, 12 to 6023
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            8152 non-null   object
#  1   month           8152 non-null   object
#  2   city            8152 non-null   object
#  3   district        8152 non-null   object
#  4   price_riyals    8152 non-null   int64
#  5   area_m2         8152 non-null   float64
#  6   no_deals        8152 non-null   int32
#  7   status          8152 non-null   object
#  8   realstate_cls   8152 non-null   object
#  9   realstate_type  8152 non-null   object
# dtypes: float64(1), int32(1), int64(1), object(7)
# memory usage: 668.7+ KB

# %% [markdown]
# ## Saving the cleaning data in other format:
# #### Complete information with missing values

# %%
# 1- saving complete dataset with missing values as excel file
df.to_excel(excel_writer = "xlsx/Makkah.xlsx", sheet_name='Makkah', index=False)

# %%
# 2- saving complete dataset with missing values as csv file
df.to_csv("csv/Makkah.csv", header=True, index=False, encoding='utf_8_sig')

# %%
# 3- saving complete dataset with missing values as json file
with open("json/Makkah.json", "w") as write_file:
    json.dump(
        df.to_json(
            orient='records', 
            double_precision=10, 
            force_ascii=False, 
            lines=True, 
            compression='infer', 
            index=True, 
            indent=4), 
        write_file
    )

# %% [markdown]
# ## Saving the cleaning data in other format:
# #### Information with no missing values

# %%
# 1- saving dataset with no missing values as excel file
df_m.to_excel(excel_writer = "xlsx/Makkah_m.xlsx", sheet_name='Makkah', index=False)

# %%
# 2- saving dataset with no missing values as csv file
df_m.to_csv("csv/Makkah_m.csv", header=True, index=False, encoding='utf_8_sig')

# %%
# 3- saving dataset with no missing values as json file
with open("json/Makkah_m.json", "w") as write_file:
    json.dump(
        df_m.to_json(
            orient='records', 
            double_precision=10, 
            force_ascii=False, 
            lines=True, 
            compression='infer', 
            index=True, 
            indent=4), 
        write_file
    )
