# %%
# Reading an excel file using Python
import numpy as np
import pandas as pd
import json

# %% [markdown]
# ## Disable warning

# %%
pd.options.mode.chained_assignment = None  # default='warn'
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Objective:
# #### dataset shape
# df_names = ["year", "month", "city", "district", "price_riyals", "area_m2", "no_deals", "status", "realstate_cls", "realstate_type"]
#
# ### Filling:
# - fill district in case of madina with "المدينة المنورة"
# - fill realstate_cls and realstate_type in case of madina with forward and then backward
# - fill realstate_cls and realstate_type in case of all other cities with "Not Available "
#
# - then Case #1 all with mean of each years , if no mean values in years then fill using foraward and backward
# - Case #2 all with median of each years , if no mean values in years then fill using foraward and backward
# - Case #3 all with foraward and backward
# - Case #4 all with backward and foraward

# %%
# read excel file
df = pd.read_excel("data/xlsx/all.xlsx")

# %%
# check the size of new data
df.shape
# Out:
# (41256, 10)

# %%
# check for first five rows
df.head()
# Out:
#    year  month    city      district  price_riyals  area_m2  no_deals  status  \
# 0  2018   مايو  الدمام  حي/1048/ ش د       1055000  2871.08         1  معتمدة
# 1  2018  يناير  الدمام   حي/1093 ش د             0     0.00         0  معتمدة
# 2  2018   مارس  الدمام   حي/1093 ش د             0     0.00         0  معتمدة
# 3  2018   مايو  الدمام   حي/1093 ش د             0     0.00         0  معتمدة
# 4  2018  يونيو  الدمام   حي/1093 ش د             0     0.00         0  معتمدة
#
#   realstate_cls realstate_type
# 0           NaN            NaN
# 1           NaN            NaN
# 2           NaN            NaN
# 3           NaN            NaN
# 4           NaN            NaN

# %%
# current statistics of data 
df.describe(include="all")
# Out:
#                 year   month         city    district  price_riyals  \
# count   41256.000000   41256        41256       40404  4.125600e+04
# unique           NaN      12            5        1659           NaN
# top              NaN  فبراير  مكة المكرمة  حي/الفيحاء           NaN
# freq             NaN    3800        19496         192           NaN
# mean     2019.500000     NaN          NaN         NaN  1.039169e+07
# std         1.118048     NaN          NaN         NaN  5.559905e+07
# min      2018.000000     NaN          NaN         NaN  0.000000e+00
# 25%      2018.750000     NaN          NaN         NaN  0.000000e+00
# 50%      2019.500000     NaN          NaN         NaN  2.800000e+05
# 75%      2020.250000     NaN          NaN         NaN  3.452188e+06
# max      2021.000000     NaN          NaN         NaN  3.000000e+09
#
#              area_m2      no_deals  status realstate_cls realstate_type
# count   4.125600e+04  41256.000000   41256           804            660
# unique           NaN           NaN       1             3             10
# top              NaN           NaN  معتمدة          سكني       قطعة أرض
# freq             NaN           NaN   41256           376            144
# mean    1.316392e+04     10.487808     NaN           NaN            NaN
# std     1.481333e+05     57.155130     NaN           NaN            NaN
# min     0.000000e+00      0.000000     NaN           NaN            NaN
# 25%     0.000000e+00      0.000000     NaN           NaN            NaN
# 50%     2.512350e+02      1.000000     NaN           NaN            NaN
# 75%     2.237617e+03      4.000000     NaN           NaN            NaN
# max     1.361769e+07   1636.000000     NaN           NaN            NaN

# %%
# current datatype of data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41256 entries, 0 to 41255
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            41256 non-null  int64
#  1   month           41256 non-null  object
#  2   city            41256 non-null  object
#  3   district        40404 non-null  object
#  4   price_riyals    41256 non-null  int64
#  5   area_m2         41256 non-null  float64
#  6   no_deals        41256 non-null  int64
#  7   status          41256 non-null  object
#  8   realstate_cls   804 non-null    object
#  9   realstate_type  660 non-null    object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 3.1+ MB

# %%
df = df.replace(0, np.nan)
df.district = df.district.str.replace('\/', ' ')

# %%
# check for first five rows
df.head()
# Out:
#    year  month    city      district  price_riyals  area_m2  no_deals  status  \
# 0  2018   مايو  الدمام  حي 1048  ش د     1055000.0  2871.08       1.0  معتمدة
# 1  2018  يناير  الدمام   حي 1093 ش د           NaN      NaN       NaN  معتمدة
# 2  2018   مارس  الدمام   حي 1093 ش د           NaN      NaN       NaN  معتمدة
# 3  2018   مايو  الدمام   حي 1093 ش د           NaN      NaN       NaN  معتمدة
# 4  2018  يونيو  الدمام   حي 1093 ش د           NaN      NaN       NaN  معتمدة
#
#   realstate_cls realstate_type
# 0           NaN            NaN
# 1           NaN            NaN
# 2           NaN            NaN
# 3           NaN            NaN
# 4           NaN            NaN

# %% [markdown]
# ### Replace month name from arabic to number
# list_month = [1, 'January', 31,
#               2, 'February', 28,
#               3,'March',31,
#               4,'April',30,
#               5,'May',31,
#               6,'June',30,
#               7,'July',31,
#               8,'August',31,
#               9,'September',30,
#               10,'October',31,
#               11,'November',30,
#               12,'December',31]

# %%
# list of arabic months
months_names = [
    'يناير',
    'فبراير',
    'مارس',
    'ابريل',
    'مايو',
    'يونيو',
    'يوليو',
    'اوغسطس',
    'سبتمبر',
    'اكتوبر',
    'نوفمبر',
    'ديسمبر'
]

# %%
# set counter to 1
i = 1
df['month_order'] = df.month

# %%
df.head()
# Out:
#    year  month    city      district  price_riyals  area_m2  no_deals  status  \
# 0  2018   مايو  الدمام  حي 1048  ش د     1055000.0  2871.08       1.0  معتمدة
# 1  2018  يناير  الدمام   حي 1093 ش د           NaN      NaN       NaN  معتمدة
# 2  2018   مارس  الدمام   حي 1093 ش د           NaN      NaN       NaN  معتمدة
# 3  2018   مايو  الدمام   حي 1093 ش د           NaN      NaN       NaN  معتمدة
# 4  2018  يونيو  الدمام   حي 1093 ش د           NaN      NaN       NaN  معتمدة
#
#   realstate_cls realstate_type month_order
# 0           NaN            NaN        مايو
# 1           NaN            NaN       يناير
# 2           NaN            NaN        مارس
# 3           NaN            NaN        مايو
# 4           NaN            NaN       يونيو

# %%
# loop for each month and create a new column month_order to corresponding month order
for month in months_names: 
    if i > 12: break 
    #if (df_fill.month_order[df_fill.month_order == month] != None):
    df.month_order[df.month_order == month] = i       
    i = i + 1

# %%
#check for result
df.month_order.unique()
# Out:
# array([5, 1, 3, 6, 7, 8, 9, 10, 12, 2, 4, 11], dtype=object)

# %%
df.head()
# Out:
#    year  month    city      district  price_riyals  area_m2  no_deals  status  \
# 0  2018   مايو  الدمام  حي 1048  ش د     1055000.0  2871.08       1.0  معتمدة
# 1  2018  يناير  الدمام   حي 1093 ش د           NaN      NaN       NaN  معتمدة
# 2  2018   مارس  الدمام   حي 1093 ش د           NaN      NaN       NaN  معتمدة
# 3  2018   مايو  الدمام   حي 1093 ش د           NaN      NaN       NaN  معتمدة
# 4  2018  يونيو  الدمام   حي 1093 ش د           NaN      NaN       NaN  معتمدة
#
#   realstate_cls realstate_type month_order
# 0           NaN            NaN           5
# 1           NaN            NaN           1
# 2           NaN            NaN           3
# 3           NaN            NaN           5
# 4           NaN            NaN           6

# %%
df.sort_values(
    by=['realstate_cls', 'realstate_type','city', 'district', 'year', 'month_order'], 
    axis=0, 
    ascending=True, 
    inplace=True, 
    kind='quicksort', 
    na_position='last', 
    ignore_index=True, 
    key=None
)

# %%
df
# Out:
#        year   month             city  \
# 0      2018    مارس  المدينة المنورة
# 1      2018  اوغسطس  المدينة المنورة
# 2      2018  سبتمبر  المدينة المنورة
# 3      2018  اكتوبر  المدينة المنورة
# 4      2018  نوفمبر  المدينة المنورة
# ...     ...     ...              ...
# 41251  2021  ديسمبر      مكة المكرمة
# 41252  2018   يوليو      مكة المكرمة
# 41253  2019   يوليو      مكة المكرمة
# 41254  2020   يوليو      مكة المكرمة
# 41255  2021   يوليو      مكة المكرمة
#
#                                                 district  price_riyals  \
# 0                                                    NaN           NaN
# 1                                                    NaN           NaN
# 2                                                    NaN           NaN
# 3                                                    NaN           NaN
# 4                                                    NaN    68000000.0
# ...                                                  ...           ...
# 41251                            حي ولى العهد للمنح رقم2           NaN
# 41252  حي يمين الذاهب الى الليث بمكة المكرمة بطريق ال...     1000000.0
# 41253  حي يمين الذاهب الى الليث بمكة المكرمة بطريق ال...           NaN
# 41254  حي يمين الذاهب الى الليث بمكة المكرمة بطريق ال...           NaN
# 41255  حي يمين الذاهب الى الليث بمكة المكرمة بطريق ال...           NaN
#
#          area_m2  no_deals  status realstate_cls realstate_type month_order
# 0            NaN       NaN  معتمدة         تجاري     أرض زراعية           3
# 1            NaN       NaN  معتمدة         تجاري     أرض زراعية           8
# 2            NaN       NaN  معتمدة         تجاري     أرض زراعية           9
# 3            NaN       NaN  معتمدة         تجاري     أرض زراعية          10
# 4      221080.20       2.0  معتمدة         تجاري     أرض زراعية          11
# ...          ...       ...     ...           ...            ...         ...
# 41251        NaN       NaN  معتمدة           NaN            NaN          12
# 41252   58029.51       1.0  معتمدة           NaN            NaN           7
# 41253        NaN       NaN  معتمدة           NaN            NaN           7
# 41254        NaN       NaN  معتمدة           NaN            NaN           7
# 41255        NaN       NaN  معتمدة           NaN            NaN           7
#
# [41256 rows x 11 columns]

# %%
# current datatype of data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41256 entries, 0 to 41255
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            41256 non-null  int64
#  1   month           41256 non-null  object
#  2   city            41256 non-null  object
#  3   district        40404 non-null  object
#  4   price_riyals    22371 non-null  float64
#  5   area_m2         22371 non-null  float64
#  6   no_deals        22371 non-null  float64
#  7   status          41256 non-null  object
#  8   realstate_cls   804 non-null    object
#  9   realstate_type  660 non-null    object
#  10  month_order     41256 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 3.5+ MB

# %%
unique_district = df.district.unique()
len(unique_district)
# Out:
# 1660

# %%
unique_district[0:10]
# Out:
# array([nan, 'حي 1048  ش د', 'حي 1093 ش د', 'حي 1145  ش د', 'حي 1168  ش د',
#        'حي 125  1', 'حي 2  183', 'حي 211  1', 'حي 245  1', 'حي 249  1'],
#       dtype=object)

# %%
unique_district = unique_district[unique_district != "المدينة المنورة"]
len(unique_district)
# Out:
# 1660

# %%
df.head()
# Out:
#    year   month             city district  price_riyals   area_m2  no_deals  \
# 0  2018    مارس  المدينة المنورة      NaN           NaN       NaN       NaN
# 1  2018  اوغسطس  المدينة المنورة      NaN           NaN       NaN       NaN
# 2  2018  سبتمبر  المدينة المنورة      NaN           NaN       NaN       NaN
# 3  2018  اكتوبر  المدينة المنورة      NaN           NaN       NaN       NaN
# 4  2018  نوفمبر  المدينة المنورة      NaN    68000000.0  221080.2       2.0
#
#    status realstate_cls realstate_type month_order
# 0  معتمدة         تجاري     أرض زراعية           3
# 1  معتمدة         تجاري     أرض زراعية           8
# 2  معتمدة         تجاري     أرض زراعية           9
# 3  معتمدة         تجاري     أرض زراعية          10
# 4  معتمدة         تجاري     أرض زراعية          11

# %%
df_1 = df[(df.city == "المدينة المنورة")]

# %%
df_1.district = df_1.district.replace(np.nan, "المدينة المنورة")

# %%
df_1
# Out:
#        year   month             city         district  price_riyals   area_m2  \
# 0      2018    مارس  المدينة المنورة  المدينة المنورة           NaN       NaN
# 1      2018  اوغسطس  المدينة المنورة  المدينة المنورة           NaN       NaN
# 2      2018  سبتمبر  المدينة المنورة  المدينة المنورة           NaN       NaN
# 3      2018  اكتوبر  المدينة المنورة  المدينة المنورة           NaN       NaN
# 4      2018  نوفمبر  المدينة المنورة  المدينة المنورة    68000000.0  221080.2
# ...     ...     ...              ...              ...           ...       ...
# 14199  2021  اوغسطس  المدينة المنورة  المدينة المنورة           NaN       NaN
# 14200  2021  سبتمبر  المدينة المنورة  المدينة المنورة           NaN       NaN
# 14201  2021  اكتوبر  المدينة المنورة  المدينة المنورة           NaN       NaN
# 14202  2021  نوفمبر  المدينة المنورة  المدينة المنورة           NaN       NaN
# 14203  2021  ديسمبر  المدينة المنورة  المدينة المنورة           NaN       NaN
#
#        no_deals  status realstate_cls realstate_type month_order
# 0           NaN  معتمدة         تجاري     أرض زراعية           3
# 1           NaN  معتمدة         تجاري     أرض زراعية           8
# 2           NaN  معتمدة         تجاري     أرض زراعية           9
# 3           NaN  معتمدة         تجاري     أرض زراعية          10
# 4           2.0  معتمدة         تجاري     أرض زراعية          11
# ...         ...     ...           ...            ...         ...
# 14199       NaN  معتمدة           NaN            NaN           8
# 14200       NaN  معتمدة           NaN            NaN           9
# 14201       NaN  معتمدة           NaN            NaN          10
# 14202       NaN  معتمدة           NaN            NaN          11
# 14203       NaN  معتمدة           NaN            NaN          12
#
# [852 rows x 11 columns]

# %%
df_1.realstate_cls = df_1.realstate_cls.ffill(axis ='rows')
df_1.realstate_cls = df_1.realstate_cls.bfill(axis ='rows')

# %%
df_1.realstate_type = df_1.realstate_type.ffill(axis ='rows')
df_1.realstate_type = df_1.realstate_type.bfill(axis ='rows')

# %%
df_1
# Out:
#        year   month             city         district  price_riyals   area_m2  \
# 0      2018    مارس  المدينة المنورة  المدينة المنورة           NaN       NaN
# 1      2018  اوغسطس  المدينة المنورة  المدينة المنورة           NaN       NaN
# 2      2018  سبتمبر  المدينة المنورة  المدينة المنورة           NaN       NaN
# 3      2018  اكتوبر  المدينة المنورة  المدينة المنورة           NaN       NaN
# 4      2018  نوفمبر  المدينة المنورة  المدينة المنورة    68000000.0  221080.2
# ...     ...     ...              ...              ...           ...       ...
# 14199  2021  اوغسطس  المدينة المنورة  المدينة المنورة           NaN       NaN
# 14200  2021  سبتمبر  المدينة المنورة  المدينة المنورة           NaN       NaN
# 14201  2021  اكتوبر  المدينة المنورة  المدينة المنورة           NaN       NaN
# 14202  2021  نوفمبر  المدينة المنورة  المدينة المنورة           NaN       NaN
# 14203  2021  ديسمبر  المدينة المنورة  المدينة المنورة           NaN       NaN
#
#        no_deals  status realstate_cls realstate_type month_order
# 0           NaN  معتمدة         تجاري     أرض زراعية           3
# 1           NaN  معتمدة         تجاري     أرض زراعية           8
# 2           NaN  معتمدة         تجاري     أرض زراعية           9
# 3           NaN  معتمدة         تجاري     أرض زراعية          10
# 4           2.0  معتمدة         تجاري     أرض زراعية          11
# ...         ...     ...           ...            ...         ...
# 14199       NaN  معتمدة          سكني       معرض/محل           8
# 14200       NaN  معتمدة          سكني       معرض/محل           9
# 14201       NaN  معتمدة          سكني       معرض/محل          10
# 14202       NaN  معتمدة          سكني       معرض/محل          11
# 14203       NaN  معتمدة          سكني       معرض/محل          12
#
# [852 rows x 11 columns]

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 852 entries, 0 to 14203
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            852 non-null    int64
#  1   month           852 non-null    object
#  2   city            852 non-null    object
#  3   district        852 non-null    object
#  4   price_riyals    513 non-null    float64
#  5   area_m2         513 non-null    float64
#  6   no_deals        513 non-null    float64
#  7   status          852 non-null    object
#  8   realstate_cls   852 non-null    object
#  9   realstate_type  852 non-null    object
#  10  month_order     852 non-null    object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 79.9+ KB

# %%
df[(df.city == "المدينة المنورة")] = df_1

# %%
df
# Out:
#        year   month             city  \
# 0      2018    مارس  المدينة المنورة
# 1      2018  اوغسطس  المدينة المنورة
# 2      2018  سبتمبر  المدينة المنورة
# 3      2018  اكتوبر  المدينة المنورة
# 4      2018  نوفمبر  المدينة المنورة
# ...     ...     ...              ...
# 41251  2021  ديسمبر      مكة المكرمة
# 41252  2018   يوليو      مكة المكرمة
# 41253  2019   يوليو      مكة المكرمة
# 41254  2020   يوليو      مكة المكرمة
# 41255  2021   يوليو      مكة المكرمة
#
#                                                 district  price_riyals  \
# 0                                        المدينة المنورة           NaN
# 1                                        المدينة المنورة           NaN
# 2                                        المدينة المنورة           NaN
# 3                                        المدينة المنورة           NaN
# 4                                        المدينة المنورة    68000000.0
# ...                                                  ...           ...
# 41251                            حي ولى العهد للمنح رقم2           NaN
# 41252  حي يمين الذاهب الى الليث بمكة المكرمة بطريق ال...     1000000.0
# 41253  حي يمين الذاهب الى الليث بمكة المكرمة بطريق ال...           NaN
# 41254  حي يمين الذاهب الى الليث بمكة المكرمة بطريق ال...           NaN
# 41255  حي يمين الذاهب الى الليث بمكة المكرمة بطريق ال...           NaN
#
#          area_m2  no_deals  status realstate_cls realstate_type month_order
# 0            NaN       NaN  معتمدة         تجاري     أرض زراعية           3
# 1            NaN       NaN  معتمدة         تجاري     أرض زراعية           8
# 2            NaN       NaN  معتمدة         تجاري     أرض زراعية           9
# 3            NaN       NaN  معتمدة         تجاري     أرض زراعية          10
# 4      221080.20       2.0  معتمدة         تجاري     أرض زراعية          11
# ...          ...       ...     ...           ...            ...         ...
# 41251        NaN       NaN  معتمدة           NaN            NaN          12
# 41252   58029.51       1.0  معتمدة           NaN            NaN           7
# 41253        NaN       NaN  معتمدة           NaN            NaN           7
# 41254        NaN       NaN  معتمدة           NaN            NaN           7
# 41255        NaN       NaN  معتمدة           NaN            NaN           7
#
# [41256 rows x 11 columns]

# %%
df_1 = df[~(df.city == "المدينة المنورة")]

# %%
df_1
# Out:
#        year   month         city  \
# 804    2018    مايو       الدمام
# 805    2019    مايو       الدمام
# 806    2020    مايو       الدمام
# 807    2021    مايو       الدمام
# 808    2018   يناير       الدمام
# ...     ...     ...          ...
# 41251  2021  ديسمبر  مكة المكرمة
# 41252  2018   يوليو  مكة المكرمة
# 41253  2019   يوليو  مكة المكرمة
# 41254  2020   يوليو  مكة المكرمة
# 41255  2021   يوليو  مكة المكرمة
#
#                                                 district  price_riyals  \
# 804                                         حي 1048  ش د     1055000.0
# 805                                         حي 1048  ش د           NaN
# 806                                         حي 1048  ش د           NaN
# 807                                         حي 1048  ش د           NaN
# 808                                          حي 1093 ش د           NaN
# ...                                                  ...           ...
# 41251                            حي ولى العهد للمنح رقم2           NaN
# 41252  حي يمين الذاهب الى الليث بمكة المكرمة بطريق ال...     1000000.0
# 41253  حي يمين الذاهب الى الليث بمكة المكرمة بطريق ال...           NaN
# 41254  حي يمين الذاهب الى الليث بمكة المكرمة بطريق ال...           NaN
# 41255  حي يمين الذاهب الى الليث بمكة المكرمة بطريق ال...           NaN
#
#         area_m2  no_deals  status realstate_cls realstate_type month_order
# 804     2871.08       1.0  معتمدة           NaN            NaN           5
# 805         NaN       NaN  معتمدة           NaN            NaN           5
# 806         NaN       NaN  معتمدة           NaN            NaN           5
# 807         NaN       NaN  معتمدة           NaN            NaN           5
# 808         NaN       NaN  معتمدة           NaN            NaN           1
# ...         ...       ...     ...           ...            ...         ...
# 41251       NaN       NaN  معتمدة           NaN            NaN          12
# 41252  58029.51       1.0  معتمدة           NaN            NaN           7
# 41253       NaN       NaN  معتمدة           NaN            NaN           7
# 41254       NaN       NaN  معتمدة           NaN            NaN           7
# 41255       NaN       NaN  معتمدة           NaN            NaN           7
#
# [40404 rows x 11 columns]

# %%
df_1.realstate_cls = df_1.realstate_cls.replace(np.nan, "Not Available")
df_1.realstate_type = df_1.realstate_type.replace(np.nan, "Not Available")

# %%
df_1
# Out:
#        year   month         city  \
# 804    2018    مايو       الدمام
# 805    2019    مايو       الدمام
# 806    2020    مايو       الدمام
# 807    2021    مايو       الدمام
# 808    2018   يناير       الدمام
# ...     ...     ...          ...
# 41251  2021  ديسمبر  مكة المكرمة
# 41252  2018   يوليو  مكة المكرمة
# 41253  2019   يوليو  مكة المكرمة
# 41254  2020   يوليو  مكة المكرمة
# 41255  2021   يوليو  مكة المكرمة
#
#                                                 district  price_riyals  \
# 804                                         حي 1048  ش د     1055000.0
# 805                                         حي 1048  ش د           NaN
# 806                                         حي 1048  ش د           NaN
# 807                                         حي 1048  ش د           NaN
# 808                                          حي 1093 ش د           NaN
# ...                                                  ...           ...
# 41251                            حي ولى العهد للمنح رقم2           NaN
# 41252  حي يمين الذاهب الى الليث بمكة المكرمة بطريق ال...     1000000.0
# 41253  حي يمين الذاهب الى الليث بمكة المكرمة بطريق ال...           NaN
# 41254  حي يمين الذاهب الى الليث بمكة المكرمة بطريق ال...           NaN
# 41255  حي يمين الذاهب الى الليث بمكة المكرمة بطريق ال...           NaN
#
#         area_m2  no_deals  status  realstate_cls realstate_type month_order
# 804     2871.08       1.0  معتمدة  Not Available  Not Available           5
# 805         NaN       NaN  معتمدة  Not Available  Not Available           5
# 806         NaN       NaN  معتمدة  Not Available  Not Available           5
# 807         NaN       NaN  معتمدة  Not Available  Not Available           5
# 808         NaN       NaN  معتمدة  Not Available  Not Available           1
# ...         ...       ...     ...            ...            ...         ...
# 41251       NaN       NaN  معتمدة  Not Available  Not Available          12
# 41252  58029.51       1.0  معتمدة  Not Available  Not Available           7
# 41253       NaN       NaN  معتمدة  Not Available  Not Available           7
# 41254       NaN       NaN  معتمدة  Not Available  Not Available           7
# 41255       NaN       NaN  معتمدة  Not Available  Not Available           7
#
# [40404 rows x 11 columns]

# %%
df[~(df.city == "المدينة المنورة")] = df_1

# %%
df
# Out:
#        year   month             city  \
# 0      2018    مارس  المدينة المنورة
# 1      2018  اوغسطس  المدينة المنورة
# 2      2018  سبتمبر  المدينة المنورة
# 3      2018  اكتوبر  المدينة المنورة
# 4      2018  نوفمبر  المدينة المنورة
# ...     ...     ...              ...
# 41251  2021  ديسمبر      مكة المكرمة
# 41252  2018   يوليو      مكة المكرمة
# 41253  2019   يوليو      مكة المكرمة
# 41254  2020   يوليو      مكة المكرمة
# 41255  2021   يوليو      مكة المكرمة
#
#                                                 district  price_riyals  \
# 0                                        المدينة المنورة           NaN
# 1                                        المدينة المنورة           NaN
# 2                                        المدينة المنورة           NaN
# 3                                        المدينة المنورة           NaN
# 4                                        المدينة المنورة    68000000.0
# ...                                                  ...           ...
# 41251                            حي ولى العهد للمنح رقم2           NaN
# 41252  حي يمين الذاهب الى الليث بمكة المكرمة بطريق ال...     1000000.0
# 41253  حي يمين الذاهب الى الليث بمكة المكرمة بطريق ال...           NaN
# 41254  حي يمين الذاهب الى الليث بمكة المكرمة بطريق ال...           NaN
# 41255  حي يمين الذاهب الى الليث بمكة المكرمة بطريق ال...           NaN
#
#          area_m2  no_deals  status  realstate_cls realstate_type month_order
# 0            NaN       NaN  معتمدة          تجاري     أرض زراعية           3
# 1            NaN       NaN  معتمدة          تجاري     أرض زراعية           8
# 2            NaN       NaN  معتمدة          تجاري     أرض زراعية           9
# 3            NaN       NaN  معتمدة          تجاري     أرض زراعية          10
# 4      221080.20       2.0  معتمدة          تجاري     أرض زراعية          11
# ...          ...       ...     ...            ...            ...         ...
# 41251        NaN       NaN  معتمدة  Not Available  Not Available          12
# 41252   58029.51       1.0  معتمدة  Not Available  Not Available           7
# 41253        NaN       NaN  معتمدة  Not Available  Not Available           7
# 41254        NaN       NaN  معتمدة  Not Available  Not Available           7
# 41255        NaN       NaN  معتمدة  Not Available  Not Available           7
#
# [41256 rows x 11 columns]

# %% [markdown]
# ### Fill empty with Mean

# %%
df_fill = df.copy()

# %%
for district in unique_district: 
    df_u = df_fill[(df_fill.district == district)]
    unique_year = df_u.year.unique()
    for year in unique_year: 
        df_y = df_u[(df_u.year == year)]
        price_fill = df_y.price_riyals.mean(skipna=True) 
        df_y.price_riyals = df_y.price_riyals.fillna(value = price_fill, method=None)
        #print(district, year, price_fill)
        area_fill = df_y.area_m2[(df_u.year == year)].mean(skipna=True) 
        df_y.area_m2 = df_y.area_m2.fillna(value = area_fill, method=None)
        #print(district, year, area_fill)
        no_deals_fill = df_y.no_deals.mean(skipna=True) 
        df_y.no_deals = df_y.no_deals.fillna(value = no_deals_fill, method=None)
        #print(district, year, no_deals_fill)
        df_u[(df_u.year == year)] = df_y
    df_fill[(df_fill.district == district)] = df_u

# %%
df_fill[df_fill.price_riyals.isna()]
# Out:
#        year   month             city  \
# 0      2018    مارس  المدينة المنورة
# 1      2018  اوغسطس  المدينة المنورة
# 2      2018  سبتمبر  المدينة المنورة
# 3      2018  اكتوبر  المدينة المنورة
# 5      2019    مارس  المدينة المنورة
# ...     ...     ...              ...
# 41238  2019  نوفمبر      مكة المكرمة
# 41239  2019  ديسمبر      مكة المكرمة
# 41253  2019   يوليو      مكة المكرمة
# 41254  2020   يوليو      مكة المكرمة
# 41255  2021   يوليو      مكة المكرمة
#
#                                                 district  price_riyals  \
# 0                                        المدينة المنورة           NaN
# 1                                        المدينة المنورة           NaN
# 2                                        المدينة المنورة           NaN
# 3                                        المدينة المنورة           NaN
# 5                                        المدينة المنورة           NaN
# ...                                                  ...           ...
# 41238                            حي ولى العهد للمنح رقم2           NaN
# 41239                            حي ولى العهد للمنح رقم2           NaN
# 41253  حي يمين الذاهب الى الليث بمكة المكرمة بطريق ال...           NaN
# 41254  حي يمين الذاهب الى الليث بمكة المكرمة بطريق ال...           NaN
# 41255  حي يمين الذاهب الى الليث بمكة المكرمة بطريق ال...           NaN
#
#        area_m2  no_deals  status  realstate_cls realstate_type month_order
# 0          NaN       NaN  معتمدة          تجاري     أرض زراعية           3
# 1          NaN       NaN  معتمدة          تجاري     أرض زراعية           8
# 2          NaN       NaN  معتمدة          تجاري     أرض زراعية           9
# 3          NaN       NaN  معتمدة          تجاري     أرض زراعية          10
# 5          NaN       NaN  معتمدة          تجاري     أرض زراعية           3
# ...        ...       ...     ...            ...            ...         ...
# 41238      NaN       NaN  معتمدة  Not Available  Not Available          11
# 41239      NaN       NaN  معتمدة  Not Available  Not Available          12
# 41253      NaN       NaN  معتمدة  Not Available  Not Available           7
# 41254      NaN       NaN  معتمدة  Not Available  Not Available           7
# 41255      NaN       NaN  معتمدة  Not Available  Not Available           7
#
# [5286 rows x 11 columns]

# %%
df_fill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41256 entries, 0 to 41255
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            41256 non-null  int64
#  1   month           41256 non-null  object
#  2   city            41256 non-null  object
#  3   district        41256 non-null  object
#  4   price_riyals    35970 non-null  float64
#  5   area_m2         35970 non-null  float64
#  6   no_deals        35970 non-null  float64
#  7   status          41256 non-null  object
#  8   realstate_cls   41256 non-null  object
#  9   realstate_type  41256 non-null  object
#  10  month_order     41256 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 3.5+ MB

# %%
for district in unique_district: 
    df_u = df_fill[(df_fill.district == district)] 
    df_u.price_riyals = df_u.price_riyals.ffill(axis ='rows')
    df_u.price_riyals = df_u.price_riyals.bfill(axis ='rows')
    #print(district, year, price_fill)
    df_u.area_m2 = df_u.area_m2.ffill(axis ='rows')
    df_u.area_m2 = df_u.area_m2.bfill(axis ='rows')
    #print(district, year, area_fill)
    df_u.no_deals = df_u.no_deals.ffill(axis ='rows')
    df_u.no_deals = df_u.no_deals.bfill(axis ='rows')
    #print(district, year, no_deals_fill)
    df_fill[(df_fill.district == district)] = df_u

# %%
df_fill[df_fill.price_riyals.isna()]
# Out:
#        year   month             city         district  price_riyals  area_m2  \
# 0      2018    مارس  المدينة المنورة  المدينة المنورة           NaN      NaN
# 1      2018  اوغسطس  المدينة المنورة  المدينة المنورة           NaN      NaN
# 2      2018  سبتمبر  المدينة المنورة  المدينة المنورة           NaN      NaN
# 3      2018  اكتوبر  المدينة المنورة  المدينة المنورة           NaN      NaN
# 5      2019    مارس  المدينة المنورة  المدينة المنورة           NaN      NaN
# ...     ...     ...              ...              ...           ...      ...
# 14199  2021  اوغسطس  المدينة المنورة  المدينة المنورة           NaN      NaN
# 14200  2021  سبتمبر  المدينة المنورة  المدينة المنورة           NaN      NaN
# 14201  2021  اكتوبر  المدينة المنورة  المدينة المنورة           NaN      NaN
# 14202  2021  نوفمبر  المدينة المنورة  المدينة المنورة           NaN      NaN
# 14203  2021  ديسمبر  المدينة المنورة  المدينة المنورة           NaN      NaN
#
#        no_deals  status realstate_cls realstate_type month_order
# 0           NaN  معتمدة         تجاري     أرض زراعية           3
# 1           NaN  معتمدة         تجاري     أرض زراعية           8
# 2           NaN  معتمدة         تجاري     أرض زراعية           9
# 3           NaN  معتمدة         تجاري     أرض زراعية          10
# 5           NaN  معتمدة         تجاري     أرض زراعية           3
# ...         ...     ...           ...            ...         ...
# 14199       NaN  معتمدة          سكني       معرض/محل           8
# 14200       NaN  معتمدة          سكني       معرض/محل           9
# 14201       NaN  معتمدة          سكني       معرض/محل          10
# 14202       NaN  معتمدة          سكني       معرض/محل          11
# 14203       NaN  معتمدة          سكني       معرض/محل          12
#
# [339 rows x 11 columns]

# %%
df_fill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41256 entries, 0 to 41255
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            41256 non-null  int64
#  1   month           41256 non-null  object
#  2   city            41256 non-null  object
#  3   district        41256 non-null  object
#  4   price_riyals    40917 non-null  float64
#  5   area_m2         40917 non-null  float64
#  6   no_deals        40917 non-null  float64
#  7   status          41256 non-null  object
#  8   realstate_cls   41256 non-null  object
#  9   realstate_type  41256 non-null  object
#  10  month_order     41256 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 3.5+ MB

# %%
df_u1 = df_fill[(df_fill.city == "المدينة المنورة")]
df_u1.shape
# Out:
# (852, 11)

# %%
unique_realstate_cls = df_u1['realstate_cls'].unique()
for realstate_cls in unique_realstate_cls: 
    df_u = df_u1[(df_u1.realstate_cls == realstate_cls)]
    unique_year = df_u.year.unique()
    for year in unique_year: 
        df_y = df_u[(df_u.year == year)]
        price_fill = df_y.price_riyals.mean(skipna=True) 
        df_y.price_riyals = df_y.price_riyals.fillna(value = price_fill, method=None)
        #print(district, year, price_fill)
        area_fill = df_y.area_m2[(df_u.year == year)].mean(skipna=True) 
        df_y.area_m2 = df_y.area_m2.fillna(value = area_fill, method=None)
        #print(district, year, area_fill)
        no_deals_fill = df_y.no_deals.mean(skipna=True) 
        df_y.no_deals = df_y.no_deals.fillna(value = no_deals_fill, method=None)
        #print(district, year, no_deals_fill)
        df_u[(df_u.year == year)] = df_y
    df_u1[(df_u1.realstate_cls == realstate_cls)] = df_u

# %%
df_u1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 852 entries, 0 to 14203
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            852 non-null    int64
#  1   month           852 non-null    object
#  2   city            852 non-null    object
#  3   district        852 non-null    object
#  4   price_riyals    852 non-null    float64
#  5   area_m2         852 non-null    float64
#  6   no_deals        852 non-null    float64
#  7   status          852 non-null    object
#  8   realstate_cls   852 non-null    object
#  9   realstate_type  852 non-null    object
#  10  month_order     852 non-null    object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 79.9+ KB

# %%
df_u1.price_riyals = df_u1.price_riyals.ffill(axis ='rows')
df_u1.price_riyals = df_u1.price_riyals.bfill(axis ='rows')

df_u1.area_m2 = df_u1.area_m2.ffill(axis ='rows')
df_u1.area_m2 = df_u1.area_m2.bfill(axis ='rows')

df_u1.no_deals = df_u1.no_deals.ffill(axis ='rows')
df_u1.no_deals = df_u1.no_deals.bfill(axis ='rows')

# %%
df_u1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 852 entries, 0 to 14203
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            852 non-null    int64
#  1   month           852 non-null    object
#  2   city            852 non-null    object
#  3   district        852 non-null    object
#  4   price_riyals    852 non-null    float64
#  5   area_m2         852 non-null    float64
#  6   no_deals        852 non-null    float64
#  7   status          852 non-null    object
#  8   realstate_cls   852 non-null    object
#  9   realstate_type  852 non-null    object
#  10  month_order     852 non-null    object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 79.9+ KB

# %%
df_fill[(df_fill.city == "المدينة المنورة")] = df_u1

# %%
df_fill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41256 entries, 0 to 41255
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            41256 non-null  int64
#  1   month           41256 non-null  object
#  2   city            41256 non-null  object
#  3   district        41256 non-null  object
#  4   price_riyals    41256 non-null  float64
#  5   area_m2         41256 non-null  float64
#  6   no_deals        41256 non-null  float64
#  7   status          41256 non-null  object
#  8   realstate_cls   41256 non-null  object
#  9   realstate_type  41256 non-null  object
#  10  month_order     41256 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 3.5+ MB

# %%
df_fill.head()
# Out:
#    year   month             city         district  price_riyals       area_m2  \
# 0  2018    مارس  المدينة المنورة  المدينة المنورة  1.017790e+08   49325.08367
# 1  2018  اوغسطس  المدينة المنورة  المدينة المنورة  1.017790e+08   49325.08367
# 2  2018  سبتمبر  المدينة المنورة  المدينة المنورة  1.017790e+08   49325.08367
# 3  2018  اكتوبر  المدينة المنورة  المدينة المنورة  1.017790e+08   49325.08367
# 4  2018  نوفمبر  المدينة المنورة  المدينة المنورة  6.800000e+07  221080.20000
#
#    no_deals  status realstate_cls realstate_type month_order
# 0     40.95  معتمدة         تجاري     أرض زراعية           3
# 1     40.95  معتمدة         تجاري     أرض زراعية           8
# 2     40.95  معتمدة         تجاري     أرض زراعية           9
# 3     40.95  معتمدة         تجاري     أرض زراعية          10
# 4      2.00  معتمدة         تجاري     أرض زراعية          11

# %%
df_fill['no_deals'] = df_fill['no_deals'].round(decimals = 0)

# %%
df_fill.head()
# Out:
#    year   month             city         district  price_riyals       area_m2  \
# 0  2018    مارس  المدينة المنورة  المدينة المنورة  1.017790e+08   49325.08367
# 1  2018  اوغسطس  المدينة المنورة  المدينة المنورة  1.017790e+08   49325.08367
# 2  2018  سبتمبر  المدينة المنورة  المدينة المنورة  1.017790e+08   49325.08367
# 3  2018  اكتوبر  المدينة المنورة  المدينة المنورة  1.017790e+08   49325.08367
# 4  2018  نوفمبر  المدينة المنورة  المدينة المنورة  6.800000e+07  221080.20000
#
#    no_deals  status realstate_cls realstate_type month_order
# 0      41.0  معتمدة         تجاري     أرض زراعية           3
# 1      41.0  معتمدة         تجاري     أرض زراعية           8
# 2      41.0  معتمدة         تجاري     أرض زراعية           9
# 3      41.0  معتمدة         تجاري     أرض زراعية          10
# 4       2.0  معتمدة         تجاري     أرض زراعية          11

# %%
df_fill[df_fill.price_riyals.isna()]
# Out:
# Empty DataFrame
# Columns: [year, month, city, district, price_riyals, area_m2, no_deals, status, realstate_cls, realstate_type, month_order]
# Index: []

# %%
df_fill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41256 entries, 0 to 41255
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            41256 non-null  int64
#  1   month           41256 non-null  object
#  2   city            41256 non-null  object
#  3   district        41256 non-null  object
#  4   price_riyals    41256 non-null  float64
#  5   area_m2         41256 non-null  float64
#  6   no_deals        41256 non-null  float64
#  7   status          41256 non-null  object
#  8   realstate_cls   41256 non-null  object
#  9   realstate_type  41256 non-null  object
#  10  month_order     41256 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 3.5+ MB

# %% [markdown]
# ## Saving the filling data with mean in other format:

# %%
# 1- saving complete dataset with missing values as excel file
df_fill.to_excel(excel_writer = "data/xlsx/all_mean.xlsx", sheet_name='all', index=False)

# %%
# 2- saving complete dataset with missing values as csv file
df_fill.to_csv("data/csv/all_mean.csv", header=True, index=False, encoding='utf_8_sig')

# %%
# 3- saving complete dataset with missing values as json file
with open("data/json/all_mean.json", "w") as write_file:
    json.dump(df_fill.to_dict('records'), write_file)  
    )

# %% [markdown]
# ### Fill empty with fill medain

# %%
df_fill = df.copy()

# %%
df_fill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41256 entries, 0 to 41255
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            41256 non-null  int64
#  1   month           41256 non-null  object
#  2   city            41256 non-null  object
#  3   district        41256 non-null  object
#  4   price_riyals    22371 non-null  float64
#  5   area_m2         22371 non-null  float64
#  6   no_deals        22371 non-null  float64
#  7   status          41256 non-null  object
#  8   realstate_cls   41256 non-null  object
#  9   realstate_type  41256 non-null  object
#  10  month_order     41256 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 3.5+ MB

# %%
for district in unique_district: 
    df_u = df_fill[(df_fill.district == district)]
    unique_year = df_u.year.unique()
    for year in unique_year: 
        df_y = df_u[(df_u.year == year)]
        price_fill = df_y.price_riyals.median(skipna=True) 
        df_y.price_riyals = df_y.price_riyals.fillna(value = price_fill, method=None)
        #print(district, year, price_fill)
        area_fill = df_y.area_m2[(df_u.year == year)].median(skipna=True) 
        df_y.area_m2 = df_y.area_m2.fillna(value = area_fill, method=None)
        #print(district, year, area_fill)
        no_deals_fill = df_y.no_deals.median(skipna=True) 
        df_y.no_deals = df_y.no_deals.fillna(value = no_deals_fill, method=None)
        #print(district, year, no_deals_fill)
        df_u[(df_u.year == year)] = df_y
    df_fill[(df_fill.district == district)] = df_u

# %%
df_fill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41256 entries, 0 to 41255
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            41256 non-null  int64
#  1   month           41256 non-null  object
#  2   city            41256 non-null  object
#  3   district        41256 non-null  object
#  4   price_riyals    35970 non-null  float64
#  5   area_m2         35970 non-null  float64
#  6   no_deals        35970 non-null  float64
#  7   status          41256 non-null  object
#  8   realstate_cls   41256 non-null  object
#  9   realstate_type  41256 non-null  object
#  10  month_order     41256 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 3.5+ MB

# %%
for district in unique_district: 
    df_u = df_fill[(df_fill.district == district)] 
    df_u.price_riyals = df_u.price_riyals.ffill(axis ='rows')
    df_u.price_riyals = df_u.price_riyals.bfill(axis ='rows')
    #print(district, year, price_fill)
    df_u.area_m2 = df_u.area_m2.ffill(axis ='rows')
    df_u.area_m2 = df_u.area_m2.bfill(axis ='rows')
    #print(district, year, area_fill)
    df_u.no_deals = df_u.no_deals.ffill(axis ='rows')
    df_u.no_deals = df_u.no_deals.bfill(axis ='rows')
    #print(district, year, no_deals_fill)
    df_fill[(df_fill.district == district)] = df_u

# %%
df_fill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41256 entries, 0 to 41255
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            41256 non-null  int64
#  1   month           41256 non-null  object
#  2   city            41256 non-null  object
#  3   district        41256 non-null  object
#  4   price_riyals    40917 non-null  float64
#  5   area_m2         40917 non-null  float64
#  6   no_deals        40917 non-null  float64
#  7   status          41256 non-null  object
#  8   realstate_cls   41256 non-null  object
#  9   realstate_type  41256 non-null  object
#  10  month_order     41256 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 3.5+ MB

# %%
df_u1 = df_fill[(df_fill.city == "المدينة المنورة")]
df_u1.shape
# Out:
# (852, 11)

# %%
unique_realstate_cls = df_u1['realstate_cls'].unique()
for realstate_cls in unique_realstate_cls: 
    df_u = df_u1[(df_u1.realstate_cls == realstate_cls)]
    unique_year = df_u.year.unique()
    for year in unique_year: 
        df_y = df_u[(df_u.year == year)]
        price_fill = df_y.price_riyals.median(skipna=True) 
        df_y.price_riyals = df_y.price_riyals.fillna(value = price_fill, method=None)
        #print(district, year, price_fill)
        area_fill = df_y.area_m2[(df_u.year == year)].median(skipna=True) 
        df_y.area_m2 = df_y.area_m2.fillna(value = area_fill, method=None)
        #print(district, year, area_fill)
        no_deals_fill = df_y.no_deals.median(skipna=True) 
        df_y.no_deals = df_y.no_deals.fillna(value = no_deals_fill, method=None)
        #print(district, year, no_deals_fill)
        df_u[(df_u.year == year)] = df_y
    df_u1[(df_u1.realstate_cls == realstate_cls)] = df_u

# %%
df_u1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 852 entries, 0 to 14203
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            852 non-null    int64
#  1   month           852 non-null    object
#  2   city            852 non-null    object
#  3   district        852 non-null    object
#  4   price_riyals    852 non-null    float64
#  5   area_m2         852 non-null    float64
#  6   no_deals        852 non-null    float64
#  7   status          852 non-null    object
#  8   realstate_cls   852 non-null    object
#  9   realstate_type  852 non-null    object
#  10  month_order     852 non-null    object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 79.9+ KB

# %%
df_u1.price_riyals = df_u1.price_riyals.ffill(axis ='rows')
df_u1.price_riyals = df_u1.price_riyals.bfill(axis ='rows')

df_u1.area_m2 = df_u1.area_m2.ffill(axis ='rows')
df_u1.area_m2 = df_u1.area_m2.bfill(axis ='rows')

df_u1.no_deals = df_u1.no_deals.ffill(axis ='rows')
df_u1.no_deals = df_u1.no_deals.bfill(axis ='rows')

# %%
df_u1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 852 entries, 0 to 14203
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            852 non-null    int64
#  1   month           852 non-null    object
#  2   city            852 non-null    object
#  3   district        852 non-null    object
#  4   price_riyals    852 non-null    float64
#  5   area_m2         852 non-null    float64
#  6   no_deals        852 non-null    float64
#  7   status          852 non-null    object
#  8   realstate_cls   852 non-null    object
#  9   realstate_type  852 non-null    object
#  10  month_order     852 non-null    object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 79.9+ KB

# %%
df_fill[(df_fill.city == "المدينة المنورة")] = df_u1

# %%
df_fill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41256 entries, 0 to 41255
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            41256 non-null  int64
#  1   month           41256 non-null  object
#  2   city            41256 non-null  object
#  3   district        41256 non-null  object
#  4   price_riyals    41256 non-null  float64
#  5   area_m2         41256 non-null  float64
#  6   no_deals        41256 non-null  float64
#  7   status          41256 non-null  object
#  8   realstate_cls   41256 non-null  object
#  9   realstate_type  41256 non-null  object
#  10  month_order     41256 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 3.5+ MB

# %%
df_fill.head()
# Out:
#    year   month             city         district  price_riyals      area_m2  \
# 0  2018    مارس  المدينة المنورة  المدينة المنورة    54387584.5   35963.7325
# 1  2018  اوغسطس  المدينة المنورة  المدينة المنورة    54387584.5   35963.7325
# 2  2018  سبتمبر  المدينة المنورة  المدينة المنورة    54387584.5   35963.7325
# 3  2018  اكتوبر  المدينة المنورة  المدينة المنورة    54387584.5   35963.7325
# 4  2018  نوفمبر  المدينة المنورة  المدينة المنورة    68000000.0  221080.2000
#
#    no_deals  status realstate_cls realstate_type month_order
# 0      48.0  معتمدة         تجاري     أرض زراعية           3
# 1      48.0  معتمدة         تجاري     أرض زراعية           8
# 2      48.0  معتمدة         تجاري     أرض زراعية           9
# 3      48.0  معتمدة         تجاري     أرض زراعية          10
# 4       2.0  معتمدة         تجاري     أرض زراعية          11

# %%
df_fill['no_deals'] = df_fill['no_deals'].round(decimals = 0)

# %%
df_fill.head()
# Out:
#    year   month             city         district  price_riyals      area_m2  \
# 0  2018    مارس  المدينة المنورة  المدينة المنورة    54387584.5   35963.7325
# 1  2018  اوغسطس  المدينة المنورة  المدينة المنورة    54387584.5   35963.7325
# 2  2018  سبتمبر  المدينة المنورة  المدينة المنورة    54387584.5   35963.7325
# 3  2018  اكتوبر  المدينة المنورة  المدينة المنورة    54387584.5   35963.7325
# 4  2018  نوفمبر  المدينة المنورة  المدينة المنورة    68000000.0  221080.2000
#
#    no_deals  status realstate_cls realstate_type month_order
# 0      48.0  معتمدة         تجاري     أرض زراعية           3
# 1      48.0  معتمدة         تجاري     أرض زراعية           8
# 2      48.0  معتمدة         تجاري     أرض زراعية           9
# 3      48.0  معتمدة         تجاري     أرض زراعية          10
# 4       2.0  معتمدة         تجاري     أرض زراعية          11

# %% [markdown]
# ## Saving the filling data with mean in other format:

# %%
# 1- saving complete dataset with missing values as excel file
df_fill.to_excel(excel_writer = "data/xlsx/all_median.xlsx", sheet_name='all', index=False)

# %%
# 2- saving complete dataset with missing values as csv file
df_fill.to_csv("data/csv/all_median.csv", header=True, index=False, encoding='utf_8_sig')

# %%
# 3- saving complete dataset with missing values as json file
with open("data/json/all_median.json", "w") as write_file:
    json.dump(df_fill.to_dict('records'), write_file)  
    )

# %% [markdown]
# ### Fill empty with fill forward and backward

# %% [markdown]
# ### Fill empty with fill forward

# %%
df_fill = df.copy()

# %%
for district in unique_district: 
    df_u = df_fill[(df_fill.district == district)] 
    df_u.price_riyals = df_u.price_riyals.ffill(axis ='rows')
    df_u.price_riyals = df_u.price_riyals.bfill(axis ='rows')
    #print(district, year, price_fill)
    df_u.area_m2 = df_u.area_m2.ffill(axis ='rows')
    df_u.area_m2 = df_u.area_m2.bfill(axis ='rows')
    #print(district, year, area_fill)
    df_u.no_deals = df_u.no_deals.ffill(axis ='rows')
    df_u.no_deals = df_u.no_deals.bfill(axis ='rows')
    #print(district, year, no_deals_fill)
    df_fill[(df_fill.district == district)] = df_u

# %%
df_fill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41256 entries, 0 to 41255
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            41256 non-null  int64
#  1   month           41256 non-null  object
#  2   city            41256 non-null  object
#  3   district        41256 non-null  object
#  4   price_riyals    40917 non-null  float64
#  5   area_m2         40917 non-null  float64
#  6   no_deals        40917 non-null  float64
#  7   status          41256 non-null  object
#  8   realstate_cls   41256 non-null  object
#  9   realstate_type  41256 non-null  object
#  10  month_order     41256 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 3.5+ MB

# %%
df_u1 = df_fill[(df_fill.city == "المدينة المنورة")]
df_u1.shape
# Out:
# (852, 11)

# %%
df_u1.price_riyals = df_u1.price_riyals.ffill(axis ='rows')
df_u1.price_riyals = df_u1.price_riyals.bfill(axis ='rows')

df_u1.area_m2 = df_u1.area_m2.ffill(axis ='rows')
df_u1.area_m2 = df_u1.area_m2.bfill(axis ='rows')

df_u1.no_deals = df_u1.no_deals.ffill(axis ='rows')
df_u1.no_deals = df_u1.no_deals.bfill(axis ='rows')

# %%
df_u1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 852 entries, 0 to 14203
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            852 non-null    int64
#  1   month           852 non-null    object
#  2   city            852 non-null    object
#  3   district        852 non-null    object
#  4   price_riyals    852 non-null    float64
#  5   area_m2         852 non-null    float64
#  6   no_deals        852 non-null    float64
#  7   status          852 non-null    object
#  8   realstate_cls   852 non-null    object
#  9   realstate_type  852 non-null    object
#  10  month_order     852 non-null    object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 79.9+ KB

# %%
df_fill[(df_fill.city == "المدينة المنورة")] = df_u1

# %%
df_fill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41256 entries, 0 to 41255
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            41256 non-null  int64
#  1   month           41256 non-null  object
#  2   city            41256 non-null  object
#  3   district        41256 non-null  object
#  4   price_riyals    41256 non-null  float64
#  5   area_m2         41256 non-null  float64
#  6   no_deals        41256 non-null  float64
#  7   status          41256 non-null  object
#  8   realstate_cls   41256 non-null  object
#  9   realstate_type  41256 non-null  object
#  10  month_order     41256 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 3.5+ MB

# %%
df_fill.head()
# Out:
#    year   month             city         district  price_riyals   area_m2  \
# 0  2018    مارس  المدينة المنورة  المدينة المنورة    68000000.0  221080.2
# 1  2018  اوغسطس  المدينة المنورة  المدينة المنورة    68000000.0  221080.2
# 2  2018  سبتمبر  المدينة المنورة  المدينة المنورة    68000000.0  221080.2
# 3  2018  اكتوبر  المدينة المنورة  المدينة المنورة    68000000.0  221080.2
# 4  2018  نوفمبر  المدينة المنورة  المدينة المنورة    68000000.0  221080.2
#
#    no_deals  status realstate_cls realstate_type month_order
# 0       2.0  معتمدة         تجاري     أرض زراعية           3
# 1       2.0  معتمدة         تجاري     أرض زراعية           8
# 2       2.0  معتمدة         تجاري     أرض زراعية           9
# 3       2.0  معتمدة         تجاري     أرض زراعية          10
# 4       2.0  معتمدة         تجاري     أرض زراعية          11

# %% [markdown]
# ## Saving the filling data with mean in other format:

# %%
# 1- saving complete dataset with missing values as excel file
df_fill.to_excel(excel_writer = "data/xlsx/all_forward.xlsx", sheet_name='all', index=False)

# %%
# 2- saving complete dataset with missing values as csv file
df_fill.to_csv("data/csv/all_forward.csv", header=True, index=False, encoding='utf_8_sig')

# %%
# 3- saving complete dataset with missing values as json file
with open("data/json/all_forward.json", "w") as write_file:
    json.dump(df_fill.to_dict('records'), write_file)  
    )

# %% [markdown]
# ### Fill empty with fill forward and backward

# %% [markdown]
# ### Fill empty with fill backward

# %%
df_fill = df.copy()

# %%
for district in unique_district: 
    df_u = df_fill[(df_fill.district == district)] 
    df_u.price_riyals = df_u.price_riyals.bfill(axis ='rows')
    df_u.price_riyals = df_u.price_riyals.ffill(axis ='rows')
    #print(district, year, price_fill)    
    df_u.area_m2 = df_u.area_m2.bfill(axis ='rows')
    df_u.area_m2 = df_u.area_m2.ffill(axis ='rows')
    #print(district, year, area_fill)    
    df_u.no_deals = df_u.no_deals.bfill(axis ='rows')
    df_u.no_deals = df_u.no_deals.ffill(axis ='rows')
    #print(district, year, no_deals_fill)
    df_fill[(df_fill.district == district)] = df_u

# %%
df_fill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41256 entries, 0 to 41255
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            41256 non-null  int64
#  1   month           41256 non-null  object
#  2   city            41256 non-null  object
#  3   district        41256 non-null  object
#  4   price_riyals    40917 non-null  float64
#  5   area_m2         40917 non-null  float64
#  6   no_deals        40917 non-null  float64
#  7   status          41256 non-null  object
#  8   realstate_cls   41256 non-null  object
#  9   realstate_type  41256 non-null  object
#  10  month_order     41256 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 3.5+ MB

# %%
df_u1 = df_fill[(df_fill.city == "المدينة المنورة")]
df_u1.shape
# Out:
# (852, 11)

# %%
df_u1.price_riyals = df_u1.price_riyals.bfill(axis ='rows')
df_u1.price_riyals = df_u1.price_riyals.ffill(axis ='rows')    

df_u1.area_m2 = df_u1.area_m2.bfill(axis ='rows')
df_u1.area_m2 = df_u1.area_m2.ffill(axis ='rows')    

df_u1.no_deals = df_u1.no_deals.bfill(axis ='rows')
df_u1.no_deals = df_u1.no_deals.ffill(axis ='rows')

# %%
df_u1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 852 entries, 0 to 14203
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            852 non-null    int64
#  1   month           852 non-null    object
#  2   city            852 non-null    object
#  3   district        852 non-null    object
#  4   price_riyals    852 non-null    float64
#  5   area_m2         852 non-null    float64
#  6   no_deals        852 non-null    float64
#  7   status          852 non-null    object
#  8   realstate_cls   852 non-null    object
#  9   realstate_type  852 non-null    object
#  10  month_order     852 non-null    object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 79.9+ KB

# %%
df_fill[(df_fill.city == "المدينة المنورة")] = df_u1

# %%
df_fill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41256 entries, 0 to 41255
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            41256 non-null  int64
#  1   month           41256 non-null  object
#  2   city            41256 non-null  object
#  3   district        41256 non-null  object
#  4   price_riyals    41256 non-null  float64
#  5   area_m2         41256 non-null  float64
#  6   no_deals        41256 non-null  float64
#  7   status          41256 non-null  object
#  8   realstate_cls   41256 non-null  object
#  9   realstate_type  41256 non-null  object
#  10  month_order     41256 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 3.5+ MB

# %%
df_fill.head()
# Out:
#    year   month             city         district  price_riyals   area_m2  \
# 0  2018    مارس  المدينة المنورة  المدينة المنورة    68000000.0  221080.2
# 1  2018  اوغسطس  المدينة المنورة  المدينة المنورة    68000000.0  221080.2
# 2  2018  سبتمبر  المدينة المنورة  المدينة المنورة    68000000.0  221080.2
# 3  2018  اكتوبر  المدينة المنورة  المدينة المنورة    68000000.0  221080.2
# 4  2018  نوفمبر  المدينة المنورة  المدينة المنورة    68000000.0  221080.2
#
#    no_deals  status realstate_cls realstate_type month_order
# 0       2.0  معتمدة         تجاري     أرض زراعية           3
# 1       2.0  معتمدة         تجاري     أرض زراعية           8
# 2       2.0  معتمدة         تجاري     أرض زراعية           9
# 3       2.0  معتمدة         تجاري     أرض زراعية          10
# 4       2.0  معتمدة         تجاري     أرض زراعية          11

# %% [markdown]
# ## Saving the filling data with mean in other format:

# %%
# 1- saving complete dataset with missing values as excel file
df_fill.to_excel(excel_writer = "data/xlsx/all_backward.xlsx", sheet_name='all', index=False)

# %%
# 2- saving complete dataset with missing values as csv file
df_fill.to_csv("data/csv/all_backward.csv", header=True, index=False, encoding='utf_8_sig')

# %%
# 3- saving complete dataset with missing values as json file
with open("data/json/all_backward.json", "w") as write_file:
    json.dump(df_fill.to_dict('records'), write_file)        
    )

# %%
df_fill.to_dict('records')
# Out:
# [{'year': 2018,
#   'month': 'مارس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 68000000.0,
#   'area_m2': 221080.2,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'أرض زراعية',
#   'month_order': 3},
#  {'year': 2018,
#   'month': 'اوغسطس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 68000000.0,
#   'area_m2': 221080.2,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'أرض زراعية',
#   'month_order': 8},
#  {'year': 2018,
#   'month': 'سبتمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 68000000.0,
#   'area_m2': 221080.2,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'أرض زراعية',
#   'month_order': 9},
#  {'year': 2018,
#   'month': 'اكتوبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 68000000.0,
#   'area_m2': 221080.2,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'أرض زراعية',
#   'month_order': 10},
#  {'year': 2018,
#   'month': 'نوفمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 68000000.0,
#   'area_m2': 221080.2,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'أرض زراعية',
#   'month_order': 11},
#  {'year': 2019,
#   'month': 'مارس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 7000000.0,
#   'area_m2': 110540.1,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'أرض زراعية',
#   'month_order': 3},
#  {'year': 2019,
#   'month': 'اوغسطس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 7000000.0,
#   'area_m2': 110540.1,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'أرض زراعية',
#   'month_order': 8},
#  {'year': 2019,
#   'month': 'سبتمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 41572200.0,
#   'area_m2': 92385.35,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'أرض زراعية',
#   'month_order': 9},
#  {'year': 2019,
#   'month': 'اكتوبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 750000.0,
#   'area_m2': 128422.06,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'أرض زراعية',
#   'month_order': 10},
#  {'year': 2019,
#   'month': 'نوفمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 700000.0,
#   'area_m2': 42532.42,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'أرض زراعية',
#   'month_order': 11},
#  {'year': 2020,
#   'month': 'مارس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 700000.0,
#   'area_m2': 42532.42,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'أرض زراعية',
#   'month_order': 3},
#  {'year': 2020,
#   'month': 'اوغسطس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 700000.0,
#   'area_m2': 42532.42,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'أرض زراعية',
#   'month_order': 8},
#  {'year': 2020,
#   'month': 'سبتمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 700000.0,
#   'area_m2': 42532.42,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'أرض زراعية',
#   'month_order': 9},
#  {'year': 2020,
#   'month': 'اكتوبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 700000.0,
#   'area_m2': 42532.42,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'أرض زراعية',
#   'month_order': 10},
#  {'year': 2020,
#   'month': 'نوفمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 700000.0,
#   'area_m2': 42532.42,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'أرض زراعية',
#   'month_order': 11},
#  {'year': 2021,
#   'month': 'مارس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 700000.0,
#   'area_m2': 42532.42,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'أرض زراعية',
#   'month_order': 3},
#  {'year': 2021,
#   'month': 'اوغسطس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 619500.0,
#   'area_m2': 286.91,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'أرض زراعية',
#   'month_order': 8},
#  {'year': 2021,
#   'month': 'سبتمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 619500.0,
#   'area_m2': 286.91,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'أرض زراعية',
#   'month_order': 9},
#  {'year': 2021,
#   'month': 'اكتوبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 619500.0,
#   'area_m2': 286.91,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'أرض زراعية',
#   'month_order': 10},
#  {'year': 2021,
#   'month': 'نوفمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 619500.0,
#   'area_m2': 286.91,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'أرض زراعية',
#   'month_order': 11},
#  {'year': 2018,
#   'month': 'يناير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 619500.0,
#   'area_m2': 286.91,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 1},
#  {'year': 2018,
#   'month': 'فبراير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 619500.0,
#   'area_m2': 286.91,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 2},
#  {'year': 2018,
#   'month': 'مارس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 619500.0,
#   'area_m2': 286.91,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 3},
#  {'year': 2018,
#   'month': 'ابريل',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 619500.0,
#   'area_m2': 286.91,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 4},
#  {'year': 2018,
#   'month': 'مايو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 200000.0,
#   'area_m2': 408.38,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 5},
#  {'year': 2018,
#   'month': 'يونيو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 50000.0,
#   'area_m2': 263.72,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 6},
#  {'year': 2018,
#   'month': 'يوليو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 127033.0,
#   'area_m2': 36.47,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 7},
#  {'year': 2018,
#   'month': 'اوغسطس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 40000.0,
#   'area_m2': 341.86,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 8},
#  {'year': 2018,
#   'month': 'سبتمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 180000.0,
#   'area_m2': 177.83,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 9},
#  {'year': 2018,
#   'month': 'اكتوبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 255000.0,
#   'area_m2': 371.26,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 10},
#  {'year': 2018,
#   'month': 'نوفمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 18590943.0,
#   'area_m2': 906.11,
#   'no_deals': 3.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 11},
#  {'year': 2018,
#   'month': 'ديسمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 7160740.0,
#   'area_m2': 234.03,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 12},
#  {'year': 2019,
#   'month': 'يناير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 7160740.0,
#   'area_m2': 234.03,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 1},
#  {'year': 2019,
#   'month': 'فبراير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 300000.0,
#   'area_m2': 105.07,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 2},
#  {'year': 2019,
#   'month': 'مارس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 8522068.0,
#   'area_m2': 694.3199999999999,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 3},
#  {'year': 2019,
#   'month': 'ابريل',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 600000.0,
#   'area_m2': 313.9,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 4},
#  {'year': 2019,
#   'month': 'مايو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 95000.0,
#   'area_m2': 206.5,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 5},
#  {'year': 2019,
#   'month': 'يونيو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 2173250.0,
#   'area_m2': 86.93,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 6},
#  {'year': 2019,
#   'month': 'يوليو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 2173250.0,
#   'area_m2': 86.93,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 7},
#  {'year': 2019,
#   'month': 'اوغسطس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 509361.0,
#   'area_m2': 336.2,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 8},
#  {'year': 2019,
#   'month': 'سبتمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 509361.0,
#   'area_m2': 336.2,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 9},
#  {'year': 2019,
#   'month': 'اكتوبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 200000.0,
#   'area_m2': 185.63,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 10},
#  {'year': 2019,
#   'month': 'نوفمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 200000.0,
#   'area_m2': 185.63,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 11},
#  {'year': 2019,
#   'month': 'ديسمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 200000.0,
#   'area_m2': 185.63,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 12},
#  {'year': 2020,
#   'month': 'يناير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 200000.0,
#   'area_m2': 185.63,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 1},
#  {'year': 2020,
#   'month': 'فبراير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 380000.0,
#   'area_m2': 2990.45,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 2},
#  {'year': 2020,
#   'month': 'مارس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 380000.0,
#   'area_m2': 2990.45,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 3},
#  {'year': 2020,
#   'month': 'ابريل',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 380000.0,
#   'area_m2': 2990.45,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 4},
#  {'year': 2020,
#   'month': 'مايو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 380000.0,
#   'area_m2': 2990.45,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 5},
#  {'year': 2020,
#   'month': 'يونيو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 380000.0,
#   'area_m2': 2990.45,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 6},
#  {'year': 2020,
#   'month': 'يوليو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 380000.0,
#   'area_m2': 2990.45,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 7},
#  {'year': 2020,
#   'month': 'اوغسطس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 380000.0,
#   'area_m2': 2990.45,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 8},
#  {'year': 2020,
#   'month': 'سبتمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 6062355.0,
#   'area_m2': 355.54,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 9},
#  {'year': 2020,
#   'month': 'اكتوبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 500000.0,
#   'area_m2': 404.44,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 10},
#  {'year': 2020,
#   'month': 'نوفمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 500000.0,
#   'area_m2': 404.44,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 11},
#  {'year': 2020,
#   'month': 'ديسمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 500000.0,
#   'area_m2': 404.44,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 12},
#  {'year': 2021,
#   'month': 'يناير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 37643341.0,
#   'area_m2': 1791.09,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 1},
#  {'year': 2021,
#   'month': 'فبراير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 37643341.0,
#   'area_m2': 1791.09,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 2},
#  {'year': 2021,
#   'month': 'مارس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 1414920.0,
#   'area_m2': 730.34,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 3},
#  {'year': 2021,
#   'month': 'ابريل',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 4956780.0,
#   'area_m2': 716.27,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 4},
#  {'year': 2021,
#   'month': 'مايو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 1550000.0,
#   'area_m2': 621.34,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 5},
#  {'year': 2021,
#   'month': 'يونيو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 1550000.0,
#   'area_m2': 621.34,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 6},
#  {'year': 2021,
#   'month': 'يوليو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 1550000.0,
#   'area_m2': 621.34,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 7},
#  {'year': 2021,
#   'month': 'اوغسطس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 1550000.0,
#   'area_m2': 621.34,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 8},
#  {'year': 2021,
#   'month': 'سبتمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 1550000.0,
#   'area_m2': 621.34,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 9},
#  {'year': 2021,
#   'month': 'اكتوبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 1550000.0,
#   'area_m2': 621.34,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 10},
#  {'year': 2021,
#   'month': 'نوفمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 1550000.0,
#   'area_m2': 621.34,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 11},
#  {'year': 2021,
#   'month': 'ديسمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 1550000.0,
#   'area_m2': 621.34,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'بيت',
#   'month_order': 12},
#  {'year': 2018,
#   'month': 'يناير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 1550000.0,
#   'area_m2': 621.34,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 1},
#  {'year': 2018,
#   'month': 'مارس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 650000.0,
#   'area_m2': 234.85,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 3},
#  {'year': 2018,
#   'month': 'ابريل',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 650000.0,
#   'area_m2': 234.85,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 4},
#  {'year': 2018,
#   'month': 'يونيو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 800000.0,
#   'area_m2': 319.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 6},
#  {'year': 2018,
#   'month': 'يوليو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 800000.0,
#   'area_m2': 319.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 7},
#  {'year': 2018,
#   'month': 'اوغسطس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 800000.0,
#   'area_m2': 319.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 8},
#  {'year': 2018,
#   'month': 'سبتمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 850000.0,
#   'area_m2': 303.05,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 9},
#  {'year': 2018,
#   'month': 'اكتوبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 850000.0,
#   'area_m2': 303.05,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 10},
#  {'year': 2018,
#   'month': 'نوفمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 850000.0,
#   'area_m2': 303.05,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 11},
#  {'year': 2018,
#   'month': 'ديسمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 850000.0,
#   'area_m2': 303.05,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 12},
#  {'year': 2019,
#   'month': 'يناير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 650000.0,
#   'area_m2': 234.85,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 1},
#  {'year': 2019,
#   'month': 'مارس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 650000.0,
#   'area_m2': 234.85,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 3},
#  {'year': 2019,
#   'month': 'ابريل',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 650000.0,
#   'area_m2': 234.85,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 4},
#  {'year': 2019,
#   'month': 'يونيو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 650000.0,
#   'area_m2': 234.85,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 6},
#  {'year': 2019,
#   'month': 'يوليو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 650000.0,
#   'area_m2': 234.85,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 7},
#  {'year': 2019,
#   'month': 'اوغسطس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 1050000.0,
#   'area_m2': 490.77,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 8},
#  {'year': 2019,
#   'month': 'سبتمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 3030000.0,
#   'area_m2': 655.92,
#   'no_deals': 3.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 9},
#  {'year': 2019,
#   'month': 'اكتوبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 2007142.0,
#   'area_m2': 700.2716,
#   'no_deals': 3.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 10},
#  {'year': 2019,
#   'month': 'نوفمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 945000.0,
#   'area_m2': 400.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 11},
#  {'year': 2019,
#   'month': 'ديسمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 945000.0,
#   'area_m2': 400.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 12},
#  {'year': 2020,
#   'month': 'يناير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 945000.0,
#   'area_m2': 400.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 1},
#  {'year': 2020,
#   'month': 'مارس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 945000.0,
#   'area_m2': 400.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 3},
#  {'year': 2020,
#   'month': 'ابريل',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 500000.0,
#   'area_m2': 400.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 4},
#  {'year': 2020,
#   'month': 'يونيو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 500000.0,
#   'area_m2': 400.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 6},
#  {'year': 2020,
#   'month': 'يوليو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 2240000.0,
#   'area_m2': 736.0,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 7},
#  {'year': 2020,
#   'month': 'اوغسطس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 2240000.0,
#   'area_m2': 736.0,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 8},
#  {'year': 2020,
#   'month': 'سبتمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 2240000.0,
#   'area_m2': 736.0,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 9},
#  {'year': 2020,
#   'month': 'اكتوبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 2240000.0,
#   'area_m2': 736.0,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 10},
#  {'year': 2020,
#   'month': 'نوفمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 2240000.0,
#   'area_m2': 736.0,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 11},
#  {'year': 2020,
#   'month': 'ديسمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 3400000.0,
#   'area_m2': 1200.0,
#   'no_deals': 3.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 12},
#  {'year': 2021,
#   'month': 'يناير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 3400000.0,
#   'area_m2': 1200.0,
#   'no_deals': 3.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 1},
#  {'year': 2021,
#   'month': 'مارس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 7500000.0,
#   'area_m2': 743.32,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 3},
#  {'year': 2021,
#   'month': 'ابريل',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 7500000.0,
#   'area_m2': 743.32,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 4},
#  {'year': 2021,
#   'month': 'يونيو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 7500000.0,
#   'area_m2': 743.32,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 6},
#  {'year': 2021,
#   'month': 'يوليو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 7500000.0,
#   'area_m2': 743.32,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 7},
#  {'year': 2021,
#   'month': 'اوغسطس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 7500000.0,
#   'area_m2': 743.32,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 8},
#  {'year': 2021,
#   'month': 'سبتمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 7500000.0,
#   'area_m2': 743.32,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 9},
#  {'year': 2021,
#   'month': 'اكتوبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 7500000.0,
#   'area_m2': 743.32,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 10},
#  {'year': 2021,
#   'month': 'نوفمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 7500000.0,
#   'area_m2': 743.32,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 11},
#  {'year': 2021,
#   'month': 'ديسمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 7500000.0,
#   'area_m2': 743.32,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'شقة',
#   'month_order': 12},
#  {'year': 2018,
#   'month': 'اكتوبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 7500000.0,
#   'area_m2': 743.32,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'عمارة',
#   'month_order': 10},
#  {'year': 2019,
#   'month': 'اكتوبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 7500000.0,
#   'area_m2': 743.32,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'عمارة',
#   'month_order': 10},
#  {'year': 2020,
#   'month': 'اكتوبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 7500000.0,
#   'area_m2': 743.32,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'عمارة',
#   'month_order': 10},
#  {'year': 2021,
#   'month': 'اكتوبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 1350000.0,
#   'area_m2': 400.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'عمارة',
#   'month_order': 10},
#  {'year': 2018,
#   'month': 'يناير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 1350000.0,
#   'area_m2': 400.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 1},
#  {'year': 2018,
#   'month': 'فبراير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 2000000.0,
#   'area_m2': 400.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 2},
#  {'year': 2018,
#   'month': 'يونيو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 2000000.0,
#   'area_m2': 400.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 6},
#  {'year': 2018,
#   'month': 'يوليو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 2000000.0,
#   'area_m2': 400.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 7},
#  {'year': 2018,
#   'month': 'اوغسطس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 2000000.0,
#   'area_m2': 400.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 8},
#  {'year': 2018,
#   'month': 'سبتمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 2000000.0,
#   'area_m2': 400.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 9},
#  {'year': 2018,
#   'month': 'اكتوبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 2000000.0,
#   'area_m2': 400.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 10},
#  {'year': 2018,
#   'month': 'نوفمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 2000000.0,
#   'area_m2': 400.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 11},
#  {'year': 2018,
#   'month': 'ديسمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 2000000.0,
#   'area_m2': 400.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 12},
#  {'year': 2019,
#   'month': 'يناير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 2000000.0,
#   'area_m2': 400.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 1},
#  {'year': 2019,
#   'month': 'فبراير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 2000000.0,
#   'area_m2': 400.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 2},
#  {'year': 2019,
#   'month': 'يونيو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 500000.0,
#   'area_m2': 400.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 6},
#  {'year': 2019,
#   'month': 'يوليو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 500000.0,
#   'area_m2': 400.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 7},
#  {'year': 2019,
#   'month': 'اوغسطس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 3866526.0,
#   'area_m2': 779.77,
#   'no_deals': 3.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 8},
#  {'year': 2019,
#   'month': 'سبتمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 3866526.0,
#   'area_m2': 779.77,
#   'no_deals': 3.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 9},
#  {'year': 2019,
#   'month': 'اكتوبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 3866526.0,
#   'area_m2': 779.77,
#   'no_deals': 3.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 10},
#  {'year': 2019,
#   'month': 'نوفمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 899178.0,
#   'area_m2': 178.29,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 11},
#  {'year': 2019,
#   'month': 'ديسمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 2741328.0,
#   'area_m2': 538.5999999999999,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 12},
#  {'year': 2020,
#   'month': 'يناير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 1975000.0,
#   'area_m2': 896.11,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 1},
#  {'year': 2020,
#   'month': 'فبراير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 2025000.0,
#   'area_m2': 883.26,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 2},
#  {'year': 2020,
#   'month': 'يونيو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 2025000.0,
#   'area_m2': 883.26,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 6},
#  {'year': 2020,
#   'month': 'يوليو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 608000.0,
#   'area_m2': 331.81,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 7},
#  {'year': 2020,
#   'month': 'اوغسطس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 608000.0,
#   'area_m2': 331.81,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 8},
#  {'year': 2020,
#   'month': 'سبتمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 1842836.0,
#   'area_m2': 762.31,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 9},
#  {'year': 2020,
#   'month': 'اكتوبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 1200000.0,
#   'area_m2': 400.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 10},
#  {'year': 2020,
#   'month': 'نوفمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 1200000.0,
#   'area_m2': 400.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 11},
#  {'year': 2020,
#   'month': 'ديسمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 1200000.0,
#   'area_m2': 400.0,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 12},
#  {'year': 2021,
#   'month': 'يناير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 133519023.0,
#   'area_m2': 131942.6166,
#   'no_deals': 113.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 1},
#  {'year': 2021,
#   'month': 'فبراير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 133519023.0,
#   'area_m2': 131942.6166,
#   'no_deals': 113.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 2},
#  {'year': 2021,
#   'month': 'يونيو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 133519023.0,
#   'area_m2': 131942.6166,
#   'no_deals': 113.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 6},
#  {'year': 2021,
#   'month': 'يوليو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 133519023.0,
#   'area_m2': 131942.6166,
#   'no_deals': 113.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 7},
#  {'year': 2021,
#   'month': 'اوغسطس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 133519023.0,
#   'area_m2': 131942.6166,
#   'no_deals': 113.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 8},
#  {'year': 2021,
#   'month': 'سبتمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 133519023.0,
#   'area_m2': 131942.6166,
#   'no_deals': 113.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 9},
#  {'year': 2021,
#   'month': 'اكتوبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 133519023.0,
#   'area_m2': 131942.6166,
#   'no_deals': 113.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 10},
#  {'year': 2021,
#   'month': 'نوفمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 133519023.0,
#   'area_m2': 131942.6166,
#   'no_deals': 113.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 11},
#  {'year': 2021,
#   'month': 'ديسمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 133519023.0,
#   'area_m2': 131942.6166,
#   'no_deals': 113.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'فيلا',
#   'month_order': 12},
#  {'year': 2018,
#   'month': 'يناير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 133519023.0,
#   'area_m2': 131942.6166,
#   'no_deals': 113.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 1},
#  {'year': 2018,
#   'month': 'فبراير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 540950380.0,
#   'area_m2': 95440.61640000001,
#   'no_deals': 83.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 2},
#  {'year': 2018,
#   'month': 'مارس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 162992983.0,
#   'area_m2': 48131.99000000001,
#   'no_deals': 57.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 3},
#  {'year': 2018,
#   'month': 'ابريل',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 359770473.0,
#   'area_m2': 69935.91,
#   'no_deals': 48.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 4},
#  {'year': 2018,
#   'month': 'مايو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 65979578.0,
#   'area_m2': 42084.55499999999,
#   'no_deals': 53.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 5},
#  {'year': 2018,
#   'month': 'يونيو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 10510164.0,
#   'area_m2': 15091.0,
#   'no_deals': 23.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 6},
#  {'year': 2018,
#   'month': 'يوليو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 93055488.0,
#   'area_m2': 54672.10000000001,
#   'no_deals': 79.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 7},
#  {'year': 2018,
#   'month': 'اوغسطس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 40201719.0,
#   'area_m2': 35633.30250000001,
#   'no_deals': 46.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 8},
#  {'year': 2018,
#   'month': 'سبتمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 177014029.0,
#   'area_m2': 34188.33899999999,
#   'no_deals': 48.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 9},
#  {'year': 2018,
#   'month': 'اكتوبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 63246059.0,
#   'area_m2': 73365.61999999997,
#   'no_deals': 96.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 10},
#  {'year': 2018,
#   'month': 'نوفمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 45529110.0,
#   'area_m2': 70686.72650000002,
#   'no_deals': 62.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 11},
#  {'year': 2018,
#   'month': 'ديسمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 247200327.0,
#   'area_m2': 83283.75739999999,
#   'no_deals': 89.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 12},
#  {'year': 2019,
#   'month': 'يناير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 98643526.0,
#   'area_m2': 71773.17749999999,
#   'no_deals': 99.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 1},
#  {'year': 2019,
#   'month': 'فبراير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 268785950.0,
#   'area_m2': 117471.08,
#   'no_deals': 92.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 2},
#  {'year': 2019,
#   'month': 'مارس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 109928637.0,
#   'area_m2': 122786.2467,
#   'no_deals': 84.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 3},
#  {'year': 2019,
#   'month': 'ابريل',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 84026334.0,
#   'area_m2': 63843.59730000002,
#   'no_deals': 80.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 4},
#  {'year': 2019,
#   'month': 'مايو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 89404841.0,
#   'area_m2': 61726.7773,
#   'no_deals': 84.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 5},
#  {'year': 2019,
#   'month': 'يونيو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 50637953.0,
#   'area_m2': 46187.5775,
#   'no_deals': 57.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 6},
#  {'year': 2019,
#   'month': 'يوليو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 88645567.0,
#   'area_m2': 139508.35,
#   'no_deals': 87.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 7},
#  {'year': 2019,
#   'month': 'اوغسطس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 72717634.0,
#   'area_m2': 53032.24359999998,
#   'no_deals': 67.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 8},
#  {'year': 2019,
#   'month': 'سبتمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 706495114.0,
#   'area_m2': 231197.3429,
#   'no_deals': 72.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 9},
#  {'year': 2019,
#   'month': 'اكتوبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 73909344.0,
#   'area_m2': 68849.79,
#   'no_deals': 86.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 10},
#  {'year': 2019,
#   'month': 'نوفمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 44545923.0,
#   'area_m2': 35210.3268,
#   'no_deals': 56.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 11},
#  {'year': 2019,
#   'month': 'ديسمبر',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 92815573.0,
#   'area_m2': 64996.30219999999,
#   'no_deals': 80.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 12},
#  {'year': 2020,
#   'month': 'يناير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 72901829.0,
#   'area_m2': 79837.05,
#   'no_deals': 102.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 1},
#  {'year': 2020,
#   'month': 'فبراير',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 130064934.0,
#   'area_m2': 89390.08499999998,
#   'no_deals': 118.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 2},
#  {'year': 2020,
#   'month': 'مارس',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 101559247.0,
#   'area_m2': 30547.503,
#   'no_deals': 51.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 3},
#  {'year': 2020,
#   'month': 'ابريل',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 162465825.0,
#   'area_m2': 151342.159,
#   'no_deals': 148.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 4},
#  {'year': 2020,
#   'month': 'مايو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 162465825.0,
#   'area_m2': 151342.159,
#   'no_deals': 148.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 5},
#  {'year': 2020,
#   'month': 'يونيو',
#   'city': 'المدينة المنورة',
#   'district': 'المدينة المنورة',
#   'price_riyals': 162465825.0,
#   'area_m2': 151342.159,
#   'no_deals': 148.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'تجاري',
#   'realstate_type': 'قطعة أرض',
#   'month_order': 6},
#  {'year': 2020,
# ...
#  {'year': 2018,
#   'month': 'نوفمبر',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 7000000.0,
#   'area_m2': 50000.9,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 11},
#  {'year': 2018,
#   'month': 'ديسمبر',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 3500000.0,
#   'area_m2': 50000.9,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 12},
#  {'year': 2019,
#   'month': 'يناير',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 3500000.0,
#   'area_m2': 50000.9,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 1},
#  {'year': 2019,
#   'month': 'فبراير',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 3500000.0,
#   'area_m2': 50000.9,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 2},
#  {'year': 2019,
#   'month': 'مارس',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 3500000.0,
#   'area_m2': 50000.9,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 3},
#  {'year': 2019,
#   'month': 'ابريل',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 2500000.0,
#   'area_m2': 80372.37,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 4},
#  {'year': 2019,
#   'month': 'مايو',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 675715.0,
#   'area_m2': 150002.7,
#   'no_deals': 3.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 5},
#  {'year': 2019,
#   'month': 'يونيو',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 675715.0,
#   'area_m2': 150002.7,
#   'no_deals': 3.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 6},
#  {'year': 2019,
#   'month': 'يوليو',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 675715.0,
#   'area_m2': 150002.7,
#   'no_deals': 3.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 7},
#  {'year': 2019,
#   'month': 'اوغسطس',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 675715.0,
#   'area_m2': 150002.7,
#   'no_deals': 3.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 8},
#  {'year': 2019,
#   'month': 'سبتمبر',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 675715.0,
#   'area_m2': 150002.7,
#   'no_deals': 3.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 9},
#  {'year': 2019,
#   'month': 'اكتوبر',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 675715.0,
#   'area_m2': 150002.7,
#   'no_deals': 3.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 10},
#  {'year': 2019,
#   'month': 'نوفمبر',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 675715.0,
#   'area_m2': 150002.7,
#   'no_deals': 3.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 11},
#  {'year': 2019,
#   'month': 'ديسمبر',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 675715.0,
#   'area_m2': 150002.7,
#   'no_deals': 3.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 12},
#  {'year': 2020,
#   'month': 'يناير',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 675715.0,
#   'area_m2': 150002.7,
#   'no_deals': 3.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 1},
#  {'year': 2020,
#   'month': 'فبراير',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 675715.0,
#   'area_m2': 150002.7,
#   'no_deals': 3.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 2},
#  {'year': 2020,
#   'month': 'مارس',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 675715.0,
#   'area_m2': 150002.7,
#   'no_deals': 3.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 3},
#  {'year': 2020,
#   'month': 'ابريل',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 675715.0,
#   'area_m2': 150002.7,
#   'no_deals': 3.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 4},
#  {'year': 2020,
#   'month': 'مايو',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 675715.0,
#   'area_m2': 150002.7,
#   'no_deals': 3.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 5},
#  {'year': 2020,
#   'month': 'يونيو',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 675715.0,
#   'area_m2': 150002.7,
#   'no_deals': 3.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 6},
#  {'year': 2020,
#   'month': 'يوليو',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 675715.0,
#   'area_m2': 150002.7,
#   'no_deals': 3.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 7},
#  {'year': 2020,
#   'month': 'اوغسطس',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 335000.0,
#   'area_m2': 100001.8,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 8},
#  {'year': 2020,
#   'month': 'سبتمبر',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 1395000.0,
#   'area_m2': 250004.5,
#   'no_deals': 5.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 9},
#  {'year': 2020,
#   'month': 'اكتوبر',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 430000.0,
#   'area_m2': 100001.8,
#   'no_deals': 2.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 10},
#  {'year': 2020,
#   'month': 'نوفمبر',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 200000.0,
#   'area_m2': 50000.9,
#   'no_deals': 1.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 11},
#  {'year': 2020,
#   'month': 'ديسمبر',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 1246000.0,
#   'area_m2': 200003.6,
#   'no_deals': 4.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 12},
#  {'year': 2021,
#   'month': 'يناير',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 3250000.0,
#   'area_m2': 200003.6,
#   'no_deals': 4.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 1},
#  {'year': 2021,
#   'month': 'فبراير',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 1155237.0,
#   'area_m2': 200003.6,
#   'no_deals': 4.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 2},
#  {'year': 2021,
#   'month': 'مارس',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 5705000.0,
#   'area_m2': 300005.4,
#   'no_deals': 6.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 3},
#  {'year': 2021,
#   'month': 'ابريل',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 3490000.0,
#   'area_m2': 250004.5,
#   'no_deals': 5.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 4},
#  {'year': 2021,
#   'month': 'مايو',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 3490000.0,
#   'area_m2': 250004.5,
#   'no_deals': 5.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 5},
#  {'year': 2021,
#   'month': 'يونيو',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 3490000.0,
#   'area_m2': 250004.5,
#   'no_deals': 5.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 6},
#  {'year': 2021,
#   'month': 'يوليو',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 3490000.0,
#   'area_m2': 250004.5,
#   'no_deals': 5.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 7},
#  {'year': 2021,
#   'month': 'اوغسطس',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 3490000.0,
#   'area_m2': 250004.5,
#   'no_deals': 5.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 8},
#  {'year': 2021,
#   'month': 'سبتمبر',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 3490000.0,
#   'area_m2': 250004.5,
#   'no_deals': 5.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 9},
#  {'year': 2021,
#   'month': 'اكتوبر',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 3490000.0,
#   'area_m2': 250004.5,
#   'no_deals': 5.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 10},
#  {'year': 2021,
#   'month': 'نوفمبر',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 3490000.0,
#   'area_m2': 250004.5,
#   'no_deals': 5.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 11},
#  {'year': 2021,
#   'month': 'ديسمبر',
#   'city': 'الدمام',
#   'district': 'حي 3143 الواقع شمال طريق الرياض الدمام السريع',
#   'price_riyals': 3490000.0,
#   'area_m2': 250004.5,
#   'no_deals': 5.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 12},
#  {'year': 2018,
#   'month': 'يناير',
#   'city': 'الدمام',
#   'district': 'حي 337  1',
#   'price_riyals': 159356339.0,
#   'area_m2': 9940.91,
#   'no_deals': 15.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 1},
#  {'year': 2018,
#   'month': 'فبراير',
#   'city': 'الدمام',
#   'district': 'حي 337  1',
#   'price_riyals': 14582480.0,
#   'area_m2': 6174.25,
#   'no_deals': 12.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 2},
#  {'year': 2018,
#   'month': 'مارس',
#   'city': 'الدمام',
#   'district': 'حي 337  1',
#   'price_riyals': 18920200.0,
#   'area_m2': 6526.17,
#   'no_deals': 16.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 3},
#  {'year': 2018,
#   'month': 'ابريل',
#   'city': 'الدمام',
#   'district': 'حي 337  1',
#   'price_riyals': 56416530.0,
#   'area_m2': 18489.85,
#   'no_deals': 12.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 4},
#  {'year': 2018,
#   'month': 'مايو',
#   'city': 'الدمام',
#   'district': 'حي 337  1',
#   'price_riyals': 51183966.0,
#   'area_m2': 18532.64,
#   'no_deals': 20.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 5},
#  {'year': 2018,
#   'month': 'يونيو',
#   'city': 'الدمام',
#   'district': 'حي 337  1',
#   'price_riyals': 18100000.0,
#   'area_m2': 7919.74,
#   'no_deals': 6.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 6},
#  {'year': 2018,
#   'month': 'يوليو',
#   'city': 'الدمام',
#   'district': 'حي 337  1',
#   'price_riyals': 17303836.0,
#   'area_m2': 6569.79,
#   'no_deals': 14.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 7},
#  {'year': 2018,
#   'month': 'اوغسطس',
#   'city': 'الدمام',
#   'district': 'حي 337  1',
#   'price_riyals': 87272417.0,
#   'area_m2': 18695.68,
#   'no_deals': 13.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 8},
#  {'year': 2018,
#   'month': 'سبتمبر',
#   'city': 'الدمام',
#   'district': 'حي 337  1',
#   'price_riyals': 95761581.0,
#   'area_m2': 34201.35,
#   'no_deals': 15.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 9},
#  {'year': 2018,
#   'month': 'اكتوبر',
#   'city': 'الدمام',
#   'district': 'حي 337  1',
#   'price_riyals': 21910350.0,
#   'area_m2': 8861.660000000002,
#   'no_deals': 16.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 10},
#  {'year': 2018,
#   'month': 'نوفمبر',
#   'city': 'الدمام',
#   'district': 'حي 337  1',
#   'price_riyals': 16718092.0,
#   'area_m2': 7574.49,
#   'no_deals': 11.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 11},
#  {'year': 2018,
#   'month': 'ديسمبر',
#   'city': 'الدمام',
#   'district': 'حي 337  1',
#   'price_riyals': 106947491.0,
#   'area_m2': 23418.68,
#   'no_deals': 30.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 12},
#  {'year': 2019,
#   'month': 'يناير',
#   'city': 'الدمام',
#   'district': 'حي 337  1',
#   'price_riyals': 13969715.0,
#   'area_m2': 7183.02,
#   'no_deals': 12.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 1},
#  {'year': 2019,
#   'month': 'فبراير',
#   'city': 'الدمام',
#   'district': 'حي 337  1',
#   'price_riyals': 44410952.0,
#   'area_m2': 10465.84,
#   'no_deals': 17.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 2},
#  {'year': 2019,
#   'month': 'مارس',
#   'city': 'الدمام',
#   'district': 'حي 337  1',
#   'price_riyals': 21438099.0,
#   'area_m2': 10165.34,
#   'no_deals': 15.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 3},
#  {'year': 2019,
#   'month': 'ابريل',
#   'city': 'الدمام',
#   'district': 'حي 337  1',
#   'price_riyals': 12610000.0,
#   'area_m2': 5517.78,
#   'no_deals': 10.0,
#   'status': 'معتمدة',
#   'realstate_cls': 'Not Available',
#   'realstate_type': 'Not Available',
#   'month_order': 4},
#  ...]

# %%
with open("sample.json", "w") as outfile:
    json.dump(df_fill.to_dict('records'), outfile)
